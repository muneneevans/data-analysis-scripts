# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

import json
from collections import OrderedDict

# %%
bg = pd.read_csv('bigml.csv')

# %%
for  x in bg.columns:
    print x
# Out:
# year
# movie
# movie_id
# certificate
# duration
# genre
# rate
# metascore
# synopsis
# votes
# box office (US)
# release_date
# user_reviews
# critic_reviews
# popularity
# awards_wins
# awards_nominations
# president
# president_party
# president_years
# country
# main_country
# budget
# opening_weekend
# opening_weekend_country
# opening_weekend_date
# oscar_best_picture_winner
# oscar_best_picture_nominee
# oscar_best_director_winner
# oscar_best_director_nominee
# oscar_best_actor_winner
# oscar_best_actor_nominee
# oscar_best_actress_winner
# oscar_best_actress_nominee
# oscar_best_adascreen_winner
# oscar_best_adascreen_nominee
# oscar_best_oriscreen_winner
# oscar_best_oriscreen_nominee
# oscar_best_supp_actor_winner
# oscar_best_supp_actor_nominee
# oscar_best_supp_actress_winner
# oscar_best_supp_actress_nominee
# oscar_best_cinematography_winner
# oscar_best_cinematography_nominee
# oscar_best_musicoriginalscore_winner
# oscar_best_musicoriginalscore_nominee
# ...

# %%
newbg=  bg[['review_score_avg','main_country', 'hollywood_film_winner',  'budget','president','certificate','genre','votes','box office (US)','user_reviews','critic_reviews','popularity','awards_wins','awards_nominations','oscar_best_picture_winner']]
newbg
# Out:
#       review_score_avg main_country has_won_oscar  hollywood_film_winner  \
# 0             6.878049          USA            No                      0
# 1             8.523255           UK            No                      0
# 2             5.250000          USA            No                      0
# 3             7.469697          USA           Yes                      0
# 4             9.808511  New Zealand           Yes                      0
# 5             7.279070          USA            No                      0
# 6             7.012048           UK            No                      0
# 7             7.688172          USA            No                      0
# 8             8.467532          USA            No                      0
# 9             8.309091          USA            No                      0
# 10            5.623529          USA            No                      0
# 11            3.948454          USA            No                      0
# ...

# %%
bp_train = newbg.head(int(newbg.shape[0]*1)).to_csv('bp_train.csv',index=False)
# bp_test = newbg.tail(int(newbg.shape[0]*.3)).to_csv('bp_test.csv',index=False)

# %%
newbg.shape[0]
# Out:
# 1153

# %%
best_actor = bg[['review_score_avg','main_country', 'hollywood_film_winner', 'budget','president','certificate','genre','votes','box office (US)','user_reviews','critic_reviews','popularity','awards_wins','awards_nominations','oscar_best_actor_winner','oscar_best_actor_nominee']]
ba_train = newbg.head(int(best_actor.shape[0]*1)).to_csv('ba_train.csv',index=False)
# ba_test = newbg.tail(int(best_actor.shape[0]*.3)).to_csv('ba_test.csv',index=False)
