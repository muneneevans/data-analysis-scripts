# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib as mp
import json
from collections import OrderedDict

# %%
#Open the excel file
mfl_excel = pd.ExcelFile('data/mfl.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
mfl_dframe = mfl_excel.parse('Facilities')
mfl_dframe
# Out:
#        Facility Code                                 Facility Name  \
# 0              19224                        CDF Kiriari Dispensary
# 1              19310    St Jude's Huruma Community Health Services
# 2              14180                               10 Engineer VCT
# 3              17486                                  12 Engineers
# 4              18393                  3Kl Maternity & Nursing Home
# 5              14181                             3KR Health Centre
# 6              11917                  78 Tank Battalion Dispensary
# 7              13043                         7Kr Mrs Health Centre
# 8              14182                             8Th Street Clinic
# 9              18137  A To Z Quality Health Family Health Services
# 10             20346                       AAR Adams Health Centre
# 11             12861                        AAR City Centre Clinic
# 12             16796           AAR Clinic Sarit Centre (Westlands)
# ...

# %%
county_name = "Embu"
county_facilities = mfl_dframe[mfl_dframe['County'] == county_name ]
beds =county_facilities[['Facility Name','Beds']]
beds[beds['Beds']>0]
# Out:
#                             Facility Name   Beds
# 54                 Acef Ena Health Centre   25.0
# 1300             Consolata Kyeni Hospital  167.0
# 1322     County Medical Centre - Embu Ltd   25.0
# 1834       Embu County Beyond Zero Clinic    1.0
# 1836     Embu Provincial General Hospital  618.0
# 2178                 Gategi Health Centre   13.0
# 2200                  Gatiruri Dispensary    4.0
# 2328                  Gitaraka Dispensary    1.0
# 2946        Ishiara Sub-District Hospital   77.0
# 3102                         Jetma Clinic    3.0
# 3162                  Joykim Nursing Home   30.0
# 3363                Kairuri Health Centre   14.0
# 3561                    Kamumu Dispensary    2.0
# 3616                     Kangaru Hospital   30.0
# 3659               Kanyuambora Dispensary    1.0
# 3887                  Karau Health Centre   25.0
# 3897                  Karerema Dispensary    4.0
# 3949                        Karurumo Rhtc   18.0
# ...

# %%
#grouped_facilities = mfl_dframe[['Beds','Facility Name']].groupby( [mfl_dframe['County'], mfl_dframe['District']])
grouped_facilities = mfl_dframe[['Beds', 'Cots','Facility Name']].groupby( [mfl_dframe['County']])
grouped_facilities

# %%
g =grouped_facilities.sum()
g
# Out:
#                    Beds    Cots
# County
# Baringo           728.0    44.0
# Bomet             837.0  1145.0
# Bungoma          1426.0    97.0
# Busia            1034.0   129.0
# Elgeyo Marakwet   807.0    33.0
# Embu             1244.0   162.0
# Garissa           805.0    73.0
# Homa Bay         1616.0   177.0
# Isiolo            549.0   146.0
# Kajiado          1293.0   165.0
# Kakamega         1931.0   323.0
# Kericho          1170.0    74.0
# Kiambu           2809.0   510.0
# Kilifi            906.0    88.0
# Kirinyaga         877.0    97.0
# Kisii            2398.0   238.0
# Kisumu           2190.0   188.0
# Kitui            1222.0   209.0
# Kwale             424.0    39.0
# Laikipia          699.0    68.0
# Lamu              159.0    20.0
# Machakos         1894.0   329.0
# Makueni          1044.0   233.0
# Mandera           475.0    51.0
# Marsabit          562.0    47.0
# Meru             1816.0   146.0
# Migori           1984.0   136.0
# Mombasa          1512.0   214.0
# ...

# %%
g
# Out:
#                    Beds    Cots
# County
# Baringo           728.0    44.0
# Bomet             837.0  1145.0
# Bungoma          1426.0    97.0
# Busia            1034.0   129.0
# Elgeyo Marakwet   807.0    33.0
# Embu             1244.0   162.0
# Garissa           805.0    73.0
# Homa Bay         1616.0   177.0
# Isiolo            549.0   146.0
# Kajiado          1293.0   165.0
# Kakamega         1931.0   323.0
# Kericho          1170.0    74.0
# Kiambu           2809.0   510.0
# Kilifi            906.0    88.0
# Kirinyaga         877.0    97.0
# Kisii            2398.0   238.0
# Kisumu           2190.0   188.0
# Kitui            1222.0   209.0
# Kwale             424.0    39.0
# Laikipia          699.0    68.0
# Lamu              159.0    20.0
# Machakos         1894.0   329.0
# Makueni          1044.0   233.0
# Mandera           475.0    51.0
# Marsabit          562.0    47.0
# Meru             1816.0   146.0
# Migori           1984.0   136.0
# Mombasa          1512.0   214.0
# ...

# %%
gn['Beds']['Baringo Central']
json.dumps(gn)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-dd48168491aa> in <module>()
# ----> 1 gn['Beds']['Baringo Central']
#       2 json.dumps(gn)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_value(self, series, key)
#    2489                     raise InvalidIndexError(key)
#    2490                 else:
# -> 2491                     raise e1
#    2492             except Exception:  # pragma: no cover
#    2493                 raise e1
#
# KeyError: 'Baringo Central'

# %%
gn = g.unstack()
gn
# Out:
#       County
# Beds  Baringo             728.0
#       Bomet               837.0
#       Bungoma            1426.0
#       Busia              1034.0
#       Elgeyo Marakwet     807.0
#       Embu               1244.0
#       Garissa             805.0
#       Homa Bay           1616.0
#       Isiolo              549.0
#       Kajiado            1293.0
#       Kakamega           1931.0
#       Kericho            1170.0
#       Kiambu             2809.0
#       Kilifi              906.0
#       Kirinyaga           877.0
#       Kisii              2398.0
#       Kisumu             2190.0
#       Kitui              1222.0
#       Kwale               424.0
#       Laikipia            699.0
#       Lamu                159.0
#       Machakos           1894.0
#       Makueni            1044.0
#       Mandera             475.0
#       Marsabit            562.0
#       Meru               1816.0
#       Migori             1984.0
#       Mombasa            1512.0
# ...

# %%
g.to_json()
# Out:
# '{"Beds":{"Baringo":728.0,"Bomet":837.0,"Bungoma":1426.0,"Busia":1034.0,"Elgeyo Marakwet":807.0,"Embu":1244.0,"Garissa":805.0,"Homa Bay":1616.0,"Isiolo":549.0,"Kajiado":1293.0,"Kakamega":1931.0,"Kericho":1170.0,"Kiambu":2809.0,"Kilifi":906.0,"Kirinyaga":877.0,"Kisii":2398.0,"Kisumu":2190.0,"Kitui":1222.0,"Kwale":424.0,"Laikipia":699.0,"Lamu":159.0,"Machakos":1894.0,"Makueni":1044.0,"Mandera":475.0,"Marsabit":562.0,"Meru":1816.0,"Migori":1984.0,"Mombasa":1512.0,"Murang\'a":752.0,"Nairobi":7357.0,"Nakuru":2496.0,"Nandi":598.0,"Narok":974.0,"Nyamira":954.0,"Nyandarua":565.0,"Nyeri":1594.0,"Samburu":522.0,"Siaya":885.0,"Taita Taveta":417.0,"Tana River":260.0,"Tharaka Nithi":826.0,"Trans Nzoia":655.0,"Turkana":849.0,"Uasin Gishu":1416.0,"Vihiga":752.0,"Wajir":507.0,"West Pokot":461.0},"Cots":{"Baringo":44.0,"Bomet":1145.0,"Bungoma":97.0,"Busia":129.0,"Elgeyo Marakwet":33.0,"Embu":162.0,"Garissa":73.0,"Homa Bay":177.0,"Isiolo":146.0,"Kajiado":165.0,"Kakamega":323.0,"Kericho":74.0,"Kiambu":
# ...

# %%
g['map'] = 0

# %%
g = g.T
g.to_json()

# %%
#map = pd.read_json('data/kenya.json')
#map = json.loads("")

# %%
with open('data/kenya.json') as data_file:
   data_string = data_file.read()    
   try:
       data_map = json.loads(data_string)
       print('Success!')
   except ValueError:
       print('Failed:')
       print(repr(data_string))

# %%
data_map['objects']['kenya2']['geometries'][0]['properties']['COUNTY']

# %%
counties = data_map['objects']['kenya2']['geometries']
counties[22]['properties']

# %%
g.loc[data_map['objects']['kenya2']['geometries'][0]['properties']['COUNTY']]['Beds']

# %%
county_ids = {}
for item in data_map['objects']['kenya2']['geometries']:
    #item['properties']['Beds']= 2.0
    #item['properties']['data_analysis'] = {
    #    "Beds": g.loc[item['properties']['COUNTY']]['Beds'],
    #    "Cots": g.loc[item['properties']['COUNTY']]['Cots'],
    #}
    #print(g.loc[item['properties']['COUNTY']]['Beds'])
    #print(g.loc[item['properties']['COUNTY']]['Beds'])
    #print(county_data)
    county

# %%
data_map2 =OrderedDict()

# %%
key_order = ('type', 'arcs', 'transform', 'objects')
json.dumps(OrderedDict((k, data_map[k]) for k in key_order))

# %%
json.dumps(data_map)

# %%
list(data_map.keys())

# %%
pd.DataFrame(data_map, columns=[x["label"] for x in data_map.io)
