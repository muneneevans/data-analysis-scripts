# %%
#import needed librar
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import json
import psycopg2
import os
import re
#

# %%
def get_connection():
    conn = {}
    with open('../db_connection/db_config_2.json') as my_file:
        db_conf = json.load(my_file)
    conn_str = "host={} dbname={} user={} password={}".format(
                db_conf['host'], db_conf['database'], 
                db_conf['user'], db_conf['passw'])
    try:
        conn = psycopg2.connect(conn_str)
        return conn
    except:
        return 'error in connecting to database'

# %%
get_connection()
# Out:
# <connection object at 0x7fa233713c80; dsn: 'host=41.89.93.180 dbname=mohdsl user=dsl password=xxxxxxx', closed: 0>

# %%
def get_products():
    ''' Get all kemsa products '''
    conn = get_connection()
    
    all_products = pd.read_sql('SELECT DISTINCT(m_product_id), product, dateordered FROM fact_kemsa_order', conn)
    
    return all_products

# %%
get_products()
# Out:
#      m_product_id                                            product  \
# 0         1001330                    SILVER SULPHADIAZINE CREAM - 1%
# 1         1001806                 WOODEN TONGUE DEPRESSOR 140MMX19MM
# 2         1000548                    SUCTION CATHETERS  - SIZE 12 FG
# 3         1001262  SODIUM LACTATE SOLUTION WITH EURO CAP/ COLLAPS...
# 4         1001261  SODIUM CHLORIDE /NORMAL SALINE SOLUTION  - 0.9...
# 5         1000743            DISPENSING LABEL  SELF-ADHESIVE X 200PC
# 6         1001261  SODIUM CHLORIDE /NORMAL SALINE SOLUTION  - 0.9...
# 7         1002930  GLUCOSE INJECTION 50%  50ML  (DEXTROSE) WITH E...
# 8         1001162         ARTEMETHER LUMEFANTRINE TABLETS - 20/120MG
# 9         1001218                       ATROPINE INJECTION  - 1MG/ML
# 10        1000234               ACETYLSALICYLIC ACID TABLETS - 300MG
# 11        1001308                  FERROUS SULPHATE TABLETS  - 200MG
# 12        1001207         ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG
# 13        1000209                PENICILLIN  BENZYL INJECTION  - 1MU
# 14        1001806                 WOODEN TONGUE DEPRESSOR 140MMX19MM
# 15        1002400                                   DIAZEPAM TAB 5MG
# 16        1000498          ZINC OXIDE STRAPPING  - SIZE 5CM 4.5M BPC
# 17        1000241                       SODIUM HYPOCHLORITE SOLUTION
# 18        1005345                   PRINTING OF MONTHLY REPORT FORMS
# 19        1000198       GENTAMICIN INJECTION - 80MG- 40MG/ML 2ML AMP
# 20        1000625                        FEEDING TUBES  - SIZE 12 FG
# 21        1000496               INFUSION GIVING SETS  WITH AIR INLET
# 22        1000175      AMOXYCILLIN / CLAVULANIC ACID TABLETS - 625MG
# 23        1002275               ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG
# 24        1001291           HYOSCINE BUTYL BROMIDE INJECTION 20MG/ML
# 25        1000198       GENTAMICIN INJECTION - 80MG- 40MG/ML 2ML AMP
# 26        1001316                         OMEPRAZOLE CAPSULES - 20MG
# 27        1000175      AMOXYCILLIN / CLAVULANIC ACID TABLETS - 625MG
# 28        1000515                               I.V. CANNULAES - 20G
# 29        1001334                           CLOTRIMAZOLE CREAM  - 1%
# ...           ...                                                ...
# 3775      1001169                   QUININE SULPHATE TABLETS - 300MG
# 3776      1001318                   CHLORPHENIRAMINE SYRUP - 2MG/5ML
# 3801  2015-12-10
# 3802  2015-10-15
# 3803  2015-10-26
# 3804  2015-10-16
#
# [3805 rows x 3 columns]

# %%
def get_year_month_product_orders(year,month):
    ''' Get all kemsa products '''
    conn = get_connection()

    query = ''' SELECT *
                FROM fact_kemsa_order
                WHERE date_part('year',  dateordered ) = %s
                AND date_part('month',  dateordered ) = %s '''%(year,month)
    all_products = pd.read_sql(query, conn)

    return all_products

# %%
get_year_month_product_orders(2015,10).columns
# Out:
# Index([u'c_order_id', u'dateordered', u'ordertype', u'ordernumber',
#        u'c_bpartner_id', u'facilitycode', u'facilitylevel', u'facilitytype',
#        u'facilityname', u'owner', u'atl_county_id', u'county',
#        u'atl_district_id', u'district', u'dnote', u'movementdate',
#        u'm_product_id', u'product', u'uom', u'm_inoutline_id', u'movementqty',
#        u'unitprice', u'linenetamt', u'qtyordered', u'productcode',
#        u'periodid'],
#       dtype='object')

# %%
# get_year_month_product_orders(1,1).columns
ps = get_year_month_product_orders(2015,10)
ps['dateordered'] = pd.to_datetime(ps['dateordered'])
ps['year'] = ps.apply(lambda row: row.dateordered.year, axis=1)
ps[['year']]
ps
# Out:
#       c_order_id dateordered ordertype             ordernumber  c_bpartner_id  \
# 0        1252624  2015-10-07       KMS  EMB-3-090960-2015/2016        1007703
# 1        1254769  2015-10-20       SPC  EMB-3-092958-2015/2016        1000830
# 2        1254769  2015-10-20       SPC  EMB-3-092958-2015/2016        1000830
# 3        1260692  2015-10-30       KMS  EMB-3-098785-2015/2016        1006631
# 4        1255956  2015-10-21       SPC  EMB-3-093346-2015/2016        1000823
# 5        1254174  2015-10-16       KMS  EMB-3-091984-2015/2016        1000608
# 6        1254700  2015-10-19       KMS  EMB-3-092679-2015/2016        1006346
# 7        1257381  2015-10-26       KMS  EMB-3-094897-2015/2016        1002068
# 8        1252616  2015-10-07       KMS  EMB-3-090905-2015/2016        1003314
# 9        1252616  2015-10-07       KMS  EMB-3-090905-2015/2016        1003314
# 10       1251843  2015-10-01       KMS  EMB-3-090047-2015/2016        1002544
# 11       1254703  2015-10-19       KMS  EMB-3-092677-2015/2016        1002337
# 12       1254174  2015-10-16       KMS  EMB-3-091984-2015/2016        1000608
# 13       1252624  2015-10-07       KMS  EMB-3-090960-2015/2016        1007703
# 14       1254700  2015-10-19       KMS  EMB-3-092679-2015/2016        1006346
# 15       1252624  2015-10-07       KMS  EMB-3-090960-2015/2016        1007703
# 16       1253400  2015-10-09       SPC  STD-3-003576-2015/2016        1000478
# 17       1254174  2015-10-16       KMS  EMB-3-091984-2015/2016        1000608
# 18       1257381  2015-10-26       KMS  EMB-3-094897-2015/2016        1002068
# 19       1254703  2015-10-19       KMS  EMB-3-092677-2015/2016        1002337
# 20       1252952  2015-10-08       SPC  EMB-3-091470-2015/2016        1001629
# 21       1251843  2015-10-01       KMS  EMB-3-090047-2015/2016        1002544
# 22       1256150  2015-10-22       SPC  EMB-3-094336-2015/2016        1001179
# 23       1260692  2015-10-30       KMS  EMB-3-098785-2015/2016        1006631
# 24       1252624  2015-10-07       KMS  EMB-3-090960-2015/2016        1007703
# 25       1260692  2015-10-30       KMS  EMB-3-098785-2015/2016        1006631
# 17           10076              2          RHF
# 18           13437              2          RHF
# 19           13870              2          RHF
# 20           12472              4          HOS
# 21           14236              2          RHF
# 22           11711              4          HOS
# 23           17722              2          RHF
# 24           14652              4          HOS
# 25           17722              2          RHF
# 26           13451              3          RHF
# 27           13451              3          RHF
# 28           13870              2          RHF
# 29           13451              3          RHF
# ...            ...            ...          ...
# 1426         11512              4          HOS
# 1427         15303              2          RHF
# 1428         11474              4          HOS
# 1429         13023              0          HOS
# 1430         13425              2          RHF
# 1431         11474              4          HOS
# 1432         15502              4          HOS
# 1433         11512              4          HOS
# 1434         10465              3          RHF
# 1435         11512              4          HOS
# 1436         15303              2          RHF
# 1437         14786              2          RHF
# 1438         11512              4          HOS
# 1439         10465              3          RHF
# 1440         13425              2          RHF
# 1441         13425              2          RHF
# 1442         13425              2          RHF
# 1443         10337              2          RHF
# 1444         11186              3          RHF
# 1445         11512              4          HOS
# 1446         13425              2          RHF
# 1447         13425              2          RHF
# 1448         10337              2          RHF
# 1449         16198              2          RHF
# 1450         10337              2          RHF
# 1451         15393              2          RHF
# 1452         13425              2          RHF
# 1453         13425              2          RHF
# 1454         16700              2          RHF
# 1455         16198              2          RHF
#
#                                 facilityname owner  ...   \
# 0                  KAJIADO DISTRICT HOSPITAL        ...
# 1     MARY HELP OF THE SICK MISSION HOSPITAL        ...
# 2     MARY HELP OF THE SICK MISSION HOSPITAL        ...
# 3                       KAPCHUMBE DISPENSARY        ...
# 4                       MAKUYU HEALTH CENTRE        ...
# 5                        BURGURET DISPENSARY        ...
# 6                          KISAKU DISPENSARY        ...
# 7             SHANTA ABAQ DISPENSARY (WAJIR)        ...
# 8                       SINGIRAINE DISPESARY        ...
# 9                       SINGIRAINE DISPESARY        ...
# 10              BARSALOI CATHOLIC DISPENSARY        ...
# 11                    NYADENDA HEALTH CENTRE        ...
# 12                       BURGURET DISPENSARY        ...
# 13                 KAJIADO DISTRICT HOSPITAL        ...
# 14                         KISAKU DISPENSARY        ...
# 15                 KAJIADO DISTRICT HOSPITAL        ...
# 16               IMENTI CENTRAL DISTRICT MOH        ...
# 17                       BURGURET DISPENSARY        ...
# 18            SHANTA ABAQ DISPENSARY (WAJIR)        ...
# 19                    NYADENDA HEALTH CENTRE        ...
# 20                MARSABIT DISTRICT HOSPITAL        ...
# 21              BARSALOI CATHOLIC DISPENSARY        ...
# 22                    NGAO DISTRICT HOSPITAL        ...
# 23                      KAPCHUMBE DISPENSARY        ...
# 24                 KAJIADO DISTRICT HOSPITAL        ...
# 25                      KAPCHUMBE DISPENSARY        ...
# 26                   WAJIR BOR HEALTH CENTRE        ...
# 27                   WAJIR BOR HEALTH CENTRE        ...
# 28                    NYADENDA HEALTH CENTRE        ...
# 29                   WAJIR BOR HEALTH CENTRE        ...
# ...                                      ...   ...  ...
# 1426                  LAMU DISTRICT HOSPITAL        ...
# 1427                        NANAM DISPENSARY        ...
# 1428                KILIFI DISTRICT HOSPITAL        ...
# 1429              KENYATTA NATIONAL HOSPITAL        ...
# 1430                         RIBA DISPENSARY        ...
# 1431                KILIFI DISTRICT HOSPITAL        ...
# 1432          RUMURUTI SUB DISTRICT HOSPITAL        ...
# 1433                  LAMU DISTRICT HOSPITAL        ...
# 1434                   KANGARI HEALTH CENTRE        ...
# 1435                  LAMU DISTRICT HOSPITAL        ...
# 1436                        NANAM DISPENSARY        ...
# 1437          KAPTIONY DISPENSARY (MARAKWET)        ...
# 1438                  LAMU DISTRICT HOSPITAL        ...
# 1439                   KANGARI HEALTH CENTRE        ...
# 1440                         RIBA DISPENSARY        ...
# 1441                         RIBA DISPENSARY        ...
# 1442                         RIBA DISPENSARY        ...
# 1443                        IGANA DISPENSARY        ...
# 1444                    WITIMA HEALTH CENTRE        ...
# 1445                  LAMU DISTRICT HOSPITAL        ...
# 1446                         RIBA DISPENSARY        ...
# 1447                         RIBA DISPENSARY        ...
# 1448                        IGANA DISPENSARY        ...
# 1449         SHIRIKISHO METHODIST DISPENSARY        ...
# 1450                        IGANA DISPENSARY        ...
# 1451               OLDONYO NYOKIE DISPENSARY        ...
# 1452                         RIBA DISPENSARY        ...
# 1453                         RIBA DISPENSARY        ...
# 1454                    NAKUKULAS DISPENSARY        ...
# 1455         SHIRIKISHO METHODIST DISPENSARY        ...
#
#                                                 product                  uom  \
# 0                 XRAY GREEN-SENSITIVE FILMS  - 30X40CM          PACK X 100S
# 1                            LAMIVUDINE TABLETS - 150MG          PACK OF 60S
# 2                             EFAVIRENZ TABLETS - 600MG          PACK OF 30S
# 3                                    MEDICINES REGISTER              BOOKLET
# 4                     FIRST RESPONSE HIV 1-2-O CARDTEST       KIT X 30 TESTS
# 5                 CHLORPHENIRAMINE INJECTION  - 10MG/ML              AMPOULE
# 6                                 I.V. CANNULAES  - 22G                PIECE
# 7          DEXTROSE - 5% WITH EURO CAP/ COLLAPSIBLE BAG                500ML
# 8         AMOXYCILLIN / CLAVULANIC ACID TABLETS - 625MG          PACK OF 10S
# 9     AMOXICILLIN/CLAVULANIC ACID ORAL SUSPENSION 31...               100 ML
# 10         GENTAMICIN INJECTION - 80MG- 40MG/ML 2ML AMP              AMPOULE
# 11                   SUTURE NYLON-2/0 75CM آ½C 40MM-RCN                DOZEN
# 12                           IBUPROFEN TABLETS  - 200MG         TIN OF 1000S
# 13                XRAY GREEN-SENSITIVE FILMS  - 24X30CM          PACK X 100S
# 14              DISPENSING LABEL  SELF-ADHESIVE X 200PC                 ROLL
# 15             HYOSCINE BUTYL BROMIDE INJECTION 20MG/ML              AMPOULE
# 16                         KIDNEY DISHES WITH LID LARGE                PIECE
# 17                  SODIUM BICARBONATE INJECTION - 8.4%              AMPOULE
# 18    GLUCOSE INJECTION 50%  50ML  (DEXTROSE) WITH E...          50ML BOTTLE
# 19                        DOXYCYCLINE CAPSULES  - 100MG         TIN OF 1000S
# 20                         CYCLOSERINE CAPSULES - 250MG          TIN OF 100S
# 21                     CHLORAMPHENICAL INJECTION  - 1GM                 VIAL
# 22    ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/2...          PACK OF 60S
# 23                         SODIUM HYPOCHLORITE SOLUTION                   5L
# 24                            PLASTER OF PARIS X (25KG)                 25KG
# 25           ERYTHROMYCIN SUSPENSION (PFR)  - 125MG/5ML               100 ML
# 26                                CEFUROXIME 250MG TABS           PACK OF 10
# 27    SODIUM CHLORIDE /NORMAL SALINE SOLUTION  - 0.9...                500ML
# 28                       CHLORPHENIRAMINE TABLETS - 4MG         TIN OF 1000S
# 29        SALBUTAMOL NEBULIZING SOLUTION  - 5MG/ML 10ML           10 ML VIAL
# ...                                                 ...                  ...
# 1426            CATHETERS FOLLEY'S 30ML  - SIZE - 16 FG                PIECE
# 1427               GLOVES  SURGEON -  SIZE 7.5  STERILE      PACK OF 50 PAIR
# 1428             ATAZANAVIR/RITONAVIR 300/100 MG TABLET          PACK OF 30S
# 1429                       PYRAZINAMIDE TABLETS - 500MG         PACK OF 100S
# 1430                PENICILLIN  BENZYL INJECTION  - 1MU                 VIAL
# 1431                       FLUCONAZOLE TABLETS  - 200MG         PACK OF 100S
# 1432                  FLUPHENAZINE INJECTION  - 25MG/ML              AMPOULE
# 1433                   HYDRALAZINE INJECTION  - 20MG/ML              AMPOULE
# 1434                          TEST KIT HIV UNIGOLD  1/2       KIT X 20 TESTS
# 1435                         SPINAL NEEDLES- 22G X 40MM                PIECE
# 1436  GLUCOSE INJECTION 50%  50ML  (DEXTROSE) WITH E...          50ML BOTTLE
# 1437             CO-TRIMOXAZOLE SUSPENSION  - 240MG/5ML          50ML BOTTLE
# 1438                  DEXAMETHASONE INJECTION  - 4MG/ML              AMPOULE
# 1439                  FIRST RESPONSE HIV 1-2-O CARDTEST       KIT X 30 TESTS
# 1440                            MATERNITY PADS (TOWELS)           PACK X 10S
# 1441         SYRINGES 2PC- 2ML  RUP WITH G23 NEEDLE X 1         PACK OF 100S
# 1442              SALBUTAMOL INHALER - 100MCG/ACTUATION  200 doses cartridge
# 1443    SUTURE NYLON NO.1 ON 90MM آ½ CIRCLE   100CM CCN                DOZEN
# 1444         GLOVES LATEX EXAMINATION DISPOSABLE MEDIUM      PACK OF 50 PAIR
# 1445           ENDOTRACHEAL   CUFFED TUBE    - SIZE 7.0                PIECE
# 1446                                 AZITHROMYCIN 500MG           PACK OF 3S
# 1447    SUTURE POLYGLACTIN  3/0 آ½ CIRCLE RBN 36MM 75CM                DOZEN
# 1448                              BISACODYL 5MG TABLETS         PACK OF 100S
# 1449                       SODIUM HYPOCHLORITE SOLUTION                   5L
# 1450             CO-TRIMOXAZOLE SUSPENSION  - 240MG/5ML          50ML BOTTLE
# 1451                      TETRACYCLINE EYE OINTMENT -1%          TUBE 3.5 GM
# 1452                     IBUPROFEN SYRUP 100MG/5ML 60ML               BOTTLE
# 1453          COTTON WOOL   ABSORB  WHITE -  400 GMS BP                 ROLL
# 1454                       SODIUM HYPOCHLORITE SOLUTION                   5L
# 1455  PHYTOMENADIONE INJECTION (VIT K1) - 10MG/ML(AD...              AMPOULE
#
#       m_inoutline_id movementqty    unitprice     linenetamt qtyordered  \
# 0            4446156          10  5593.728000   55937.280000         10
# 1            4479542          25   185.874604    4646.865100         25
# 2            4479540          47   341.781000   16063.707000         47
# 3            4508405           1   340.000000     340.000000          1
# 4            4471293           1  2180.058720    2180.058720          1
# 5            4457459          20     4.500000      90.000000         20
# 6            4464667          40     9.744000     389.760000         40
# 19    PM01DXY001     None  2015
# 20    PM01CYC002     None  2015
# 21    PM01CAF002     None  2015
# 22    PM04ZDV006     None  2015
# 23    PD01SHS001     None  2015
# 24    NM13DEN111     None  2015
# 25    PM01ERY001     None  2015
# 26    PM01CEF005     None  2015
# 27    PM09SDU002     None  2015
# 28    PM13CHL004     None  2015
# 29    PM13SAL003     None  2015
# ...          ...      ...   ...
# 1426  NM02CAT006     None  2015
# 1427  NM07GLV006     None  2015
# 1428  PM04RTV002     None  2015
# 1429  PM01PYR001     None  2015
# 1430  PM01PEN002     None  2015
# 1431  PM02FLU002     None  2015
# 1432  PM07FLE001     None  2015
# 1433  PM06HYD001     None  2015
# 1434  NL05TES004     None  2015
# 1435  NM12NED007     None  2015
# 1436  PM09DEX006     None  2015
# 1437  PM01CTX001     None  2015
# 1438  PM10DEX001     None  2015
# 1439  NL05TES069     None  2015
# 1440  NM19MAT005     None  2015
# 1441  NM10SYR004     None  2015
# 1442  PM13SAL001     None  2015
# 1443  NM03SUT067     None  2015
# 1444  NM07GLV001     None  2015
# 1445  NM05TUB004     None  2015
# 1446  PM01AZT005     None  2015
# 1447  NM03SUT093     None  2015
# 1448  PM11BAS001     None  2015
# 1449  PD01SHS001     None  2015
# 1450  PM01CTX001     None  2015
# 1451  PM12TET002     None  2015
# 1452  PM05BRU003     None  2015
# 1453  NM01CTW001     None  2015
# 1454  PD01SHS001     None  2015
# 1455  PM14PHY001     None  2015
#
# [1456 rows x 27 columns]

# %%
ps[ps['movementdate'] == '0180-10-01']
# Out:
# Empty DataFrame
# Columns: [c_order_id, dateordered, ordertype, ordernumber, c_bpartner_id, facilitycode, facilitylevel, facilitytype, facilityname, owner, atl_county_id, county, atl_district_id, district, dnote, movementdate, m_product_id, product, uom, m_inoutline_id, movementqty, unitprice, linenetamt, qtyordered, productcode, periodid, year]
# Index: []
#
# [0 rows x 27 columns]

# %%
def get_facility_year_products(facility_id,year):
    ''' Return a list of all products that have been ordered by the facility'''
    query = """ SELECT  a.m_product_id as id, a.product as name , a.dateordered, a.ordernumber, 
                        a.movementdate, a.movementqty as quantity, a.unitprice, a.qtyordered as quantity_ordered, a.periodid, 
                        b.id as facility_id, b.name as facility_name
                FROM fact_kemsa_order a, facilities_facility b
                WHERE a.facilitycode = b.code
                AND   b.id = '%s' 
                AND date_part('year',  a.dateordered ) = %s"""%(facility_id,year)
    facility_products =  pd.read_sql(query,get_connection())
    
    return facility_products

# %%
drugs = get_facility_year_products('2e21b2de-7c5b-4db7-bb1d-26930af9274d', 2015)
drugs['month'] = drugs.apply(lambda row: row.dateordered.month, axis=1)
# drugs = drugs.groupby([,])
functions = {'quantity':['sum'], 'unitprice': ['mean'], 'quantity_ordered':'sum' , 'month': {'month' :(lambda x: x )}, 'name': {'name': ( lambda x: x )}}
drugs = drugs.groupby(['id']).agg(functions)
drugs.swaplevel(i=0,j=1, axis=1)
drugs.columns = drugs.columns.droplevel()
drugs
# Out:
#         month         mean   sum  \
# id
# 1000171    10  1845.360000   108
# 1000204    10   281.094139    24
# 1001151     7  1645.610000   800
# 1001156     7   429.478777  1329
# 1001158     7  2901.540985    16
# 1001172     7   115.164000   270
# 1001188     7   809.993250  1200
# 1001206     7   202.337876   255
# 1001207     7   591.850000  5200
# 1001208     7   268.968000  1662
# 1001213     7   500.250000    10
# 1002050     7   981.810000  5700
# 1002275     7   281.240000   579
# 1003743    []   186.543900  6000
# 1004903     7  1584.825000   120
# 1005343     7   145.956200   150
#
#                                                       name   sum
# id
# 1000171                  TB PATIENT PACK CATEGORY I&III 6M   108
# 1000204                       PYRAZINAMIDE TABLETS - 500MG    24
# 1001151            LOPINAVIR /RITONAVIR TABLETS - 200/50MG   800
# 1001156            TENOFOVIR300MG /LAMIVUDINE300MG TABLETS  1329
# 1001158    LOPINAVIR /RITONAVIR ORAL SOLUTION - 80/20MG/ML    16
# 1001172               NEVIRAPINE ORAL SUSPENSION - 10MG/ML   270
# 1001188  ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/2...  1200
# 1001206                         LAMIVUDINE TABLETS - 150MG   255
# 1001207         ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG  5200
# 1001208                         NEVIRAPINE TABLETS - 200MG  1662
# 1001213                  ZIDOVUDINE (AZT) TABLETS  - 300MG    10
# 1002050  TENOFOVIR 300MG/LAMIVUDINE 300MG /EFAVIRENZ  6...  5700
# 1002275               ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG   579
# 1003743                                                 []  3000
# 1004903             ATAZANAVIR/RITONAVIR 300/100 MG TABLET   120
# 1005343                        DAPSONE 100MG TABLETS 100'S   150

# %%
drugs = get_facility_year_products('2e21b2de-7c5b-4db7-bb1d-26930af9274d', 2015)
drugs['month'] = drugs.apply(lambda row: row.dateordered.month, axis=1)
# drugs = drugs.groupby([,])
functions = {'quantity':['sum'], 'unitprice': ['mean'], 'quantity_ordered':'sum'}
drugs = drugs.groupby(['month','id', 'name']).agg(functions)
drugs.swaplevel(i=0,j=1, axis=1)
drugs.columns = drugs.columns.droplevel()
drugs
# Out:
#                                                                          mean  \
# month id      name
# 7     1001151 LOPINAVIR /RITONAVIR TABLETS - 200/50MG             1645.610000
#       1001156 TENOFOVIR300MG /LAMIVUDINE300MG TABLETS              429.478777
#       1001158 LOPINAVIR /RITONAVIR ORAL SOLUTION - 80/20MG/ML     2901.540985
#       1001172 NEVIRAPINE ORAL SUSPENSION - 10MG/ML                 115.164000
#       1001188 ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/200MG   809.993250
#       1001206 LAMIVUDINE TABLETS - 150MG                           202.337876
#       1001207 ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG           591.850000
#       1001208 NEVIRAPINE TABLETS - 200MG                           268.968000
#       1001213 ZIDOVUDINE (AZT) TABLETS  - 300MG                    500.250000
#       1002050 TENOFOVIR 300MG/LAMIVUDINE 300MG /EFAVIRENZ  600MG   981.810000
#       1002275 ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG                 281.240000
#       1003743 COTRIMOXAZOLE 960MG TABLETS 100S                     186.543900
#       1004903 ATAZANAVIR/RITONAVIR 300/100 MG TABLET              1584.825000
#       1005343 DAPSONE 100MG TABLETS 100'S                          145.956200
# 10    1000171 TB PATIENT PACK CATEGORY I&III 6M                   1845.360000
#       1000204 PYRAZINAMIDE TABLETS - 500MG                         281.094139
#
#                                                                    sum   sum
# month id      name
# 7     1001151 LOPINAVIR /RITONAVIR TABLETS - 200/50MG              800   800
#       1001156 TENOFOVIR300MG /LAMIVUDINE300MG TABLETS             1329  1329
#       1001158 LOPINAVIR /RITONAVIR ORAL SOLUTION - 80/20MG/ML       16    16
#       1001172 NEVIRAPINE ORAL SUSPENSION - 10MG/ML                 270   270
#       1001188 ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/200MG  1200  1200
#       1001206 LAMIVUDINE TABLETS - 150MG                           255   255
#       1001207 ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG          5200  5200
#       1001208 NEVIRAPINE TABLETS - 200MG                          1662  1662
#       1001213 ZIDOVUDINE (AZT) TABLETS  - 300MG                     10    10
#       1002050 TENOFOVIR 300MG/LAMIVUDINE 300MG /EFAVIRENZ  600MG  5700  5700
#       1002275 ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG                 579   579
#       1003743 COTRIMOXAZOLE 960MG TABLETS 100S                    6000  3000
#       1004903 ATAZANAVIR/RITONAVIR 300/100 MG TABLET               120   120
#       1005343 DAPSONE 100MG TABLETS 100'S                          150   150
# 10    1000171 TB PATIENT PACK CATEGORY I&III 6M                    108   108
#       1000204 PYRAZINAMIDE TABLETS - 500MG                          24    24

# %%
drugs.swaplevel(i=0,j=1, axis=1)
drugs.
# Out:
#                                                                          mean  \
#                                                                     unitprice
# month id      name
# 7     1001151 LOPINAVIR /RITONAVIR TABLETS - 200/50MG             1645.610000
#       1001156 TENOFOVIR300MG /LAMIVUDINE300MG TABLETS              429.478777
#       1001158 LOPINAVIR /RITONAVIR ORAL SOLUTION - 80/20MG/ML     2901.540985
#       1001172 NEVIRAPINE ORAL SUSPENSION - 10MG/ML                 115.164000
#       1001188 ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/200MG   809.993250
#       1001206 LAMIVUDINE TABLETS - 150MG                           202.337876
#       1001207 ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG           591.850000
#       1001208 NEVIRAPINE TABLETS - 200MG                           268.968000
#       1001213 ZIDOVUDINE (AZT) TABLETS  - 300MG                    500.250000
#       1002050 TENOFOVIR 300MG/LAMIVUDINE 300MG /EFAVIRENZ  600MG   981.810000
#       1002275 ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG                 281.240000
#       1003743 COTRIMOXAZOLE 960MG TABLETS 100S                     186.543900
#       1004903 ATAZANAVIR/RITONAVIR 300/100 MG TABLET              1584.825000
#       1005343 DAPSONE 100MG TABLETS 100'S                          145.956200
# 10    1000171 TB PATIENT PACK CATEGORY I&III 6M                   1845.360000
#       1000204 PYRAZINAMIDE TABLETS - 500MG                         281.094139
#
#                                                                               sum  \
#                                                                  quantity_ordered
# month id      name
# 7     1001151 LOPINAVIR /RITONAVIR TABLETS - 200/50MG                         800
#       1001156 TENOFOVIR300MG /LAMIVUDINE300MG TABLETS                        1329
#       1001158 LOPINAVIR /RITONAVIR ORAL SOLUTION - 80/20MG/ML                  16
#       1001172 NEVIRAPINE ORAL SUSPENSION - 10MG/ML                            270
#       1001188 ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/200MG             1200
#       1001206 LAMIVUDINE TABLETS - 150MG                                      255
#       1001207 ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG                     5200
#       1001208 NEVIRAPINE TABLETS - 200MG                                     1662
#       1001213 ZIDOVUDINE (AZT) TABLETS  - 300MG                                10
#       1002050 TENOFOVIR 300MG/LAMIVUDINE 300MG /EFAVIRENZ  600MG             5700
#       1002275 ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG                            579
#       1003743 COTRIMOXAZOLE 960MG TABLETS 100S                               6000
#       1004903 ATAZANAVIR/RITONAVIR 300/100 MG TABLET                          120
#       1005343 DAPSONE 100MG TABLETS 100'S                                     150
# 10    1000171 TB PATIENT PACK CATEGORY I&III 6M                               108
#       1000204 PYRAZINAMIDE TABLETS - 500MG                                     24
#
#
#                                                                  quantity
# month id      name
# 7     1001151 LOPINAVIR /RITONAVIR TABLETS - 200/50MG                 800
#       1001156 TENOFOVIR300MG /LAMIVUDINE300MG TABLETS                1329
#       1001158 LOPINAVIR /RITONAVIR ORAL SOLUTION - 80/20MG/ML          16
#       1001172 NEVIRAPINE ORAL SUSPENSION - 10MG/ML                    270
#       1001188 ZIDOVUDINE /LAMIVUDINE /NEVIRAPINE - 300/150/200MG     1200
#       1001206 LAMIVUDINE TABLETS - 150MG                              255
#       1001207 ZIDOVUDINE/LAMIVUDINE/ TABLETS - 300/150MG             5200
#       1001208 NEVIRAPINE TABLETS - 200MG                             1662
#       1001213 ZIDOVUDINE (AZT) TABLETS  - 300MG                        10
#       1002050 TENOFOVIR 300MG/LAMIVUDINE 300MG /EFAVIRENZ  600MG     5700
#       1002275 ABACAVIR/LAMIVUDINE/ TABLETS 60/30MG                    579
#       1003743 COTRIMOXAZOLE 960MG TABLETS 100S                       3000
#       1004903 ATAZANAVIR/RITONAVIR 300/100 MG TABLET                  120
#       1005343 DAPSONE 100MG TABLETS 100'S                             150
# 10    1000171 TB PATIENT PACK CATEGORY I&III 6M                       108
#       1000204 PYRAZINAMIDE TABLETS - 500MG                             24

# %%
pd.read_sql( ('''SELECT * FROM facilities_facility WHERE code = '%s' ''')%(13425), get_connection() )
# Out:
#                                      id  deleted  active             name  \
# 0  87b36d6c-48a4-41df-bc75-4d7f89fe1842    False    True  Riba Dispensary
#
#      official_name   code registration_number abbreviation description  \
# 0  Riba Dispensary  13425                None         None        None
#
#    number_of_beds     ...       _effectivefrom  _effectiveto  \
# 0               0     ...           1900-01-01    2199-12-31
#
#                                 ward_id                      facility_type_id  \
# 0  c084a67b-36f0-4795-b8d1-5f50e9526da2  6511a5d0-eaca-47fe-b953-2ba5831e21b5
#
#                           keph_level_id                              owner_id  \
# 0  7b8cced5-f9a1-4f18-aa2e-f2241ef9c984  1b0b8814-a3d0-4e76-bfc9-4dea62a58b60
#
#    parent_id sub_county_id                               town_id  facility_sk
# 0       None          None  918f97a2-ae2d-4768-9406-8e646a42207a         3844
#
# [1 rows x 48 columns]
