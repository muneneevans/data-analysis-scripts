# %%
#import needed librar
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import json
import psycopg2
import os
import re
#

# %%
def static_vars(**kwargs):
    def decorate(func):
        for k in kwargs:
            setattr(func, k, kwargs[k])
        return func
    return decorate

# %%
def get_connection():
    
    with open('../db_connection/db_config_2.json') as my_file:
        db_conf = json.load(my_file)
    conn_str = "host={} dbname={} user={} password={}".format(
                db_conf['host'], db_conf['database'], 
                db_conf['user'], db_conf['passw'])
    try:
        if not hasattr(get_connection, "conn"):            
            get_connection.conn = psycopg2.connect(conn_str)
            return get_connection.conn
        else:            
            return get_connection.conn
        return conn
    except('error'):
        return 'error in connecting to database'

# %%
get_connection()
# Out:
# <connection object at 0x7f71e0260a10; dsn: 'host=41.89.93.180 password=xxx user=dsl dbname=mohdsl', closed: 0>

# %%
def get_indicator_groups():
    '''return a list of all indicator groups'''
    conn = get_connection()
    
    all_indicator_groups = DataFrame()
    
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_indicatorgroup', con=conn, chunksize=100):
        all_indicator_groups = all_indicator_groups.append(chunk)
    
    return all_indicator_groups

# %%
get_indicator_groups()
# Out:
#     indicatorgroupid                                   name          uid  \
# 0             412980         HIV care and treatment-MOH 711  Ym44sNLgAnM
# 1             276490                                 MOH731  JKQJGg8QXcv
# 2             420575                   HEI Cohort Analysis   pd24ijrPxT8
# 3             423659                 Immunization Logistics  L5ypsqd9vf7
# 4             179062                       Service Workload  kgtSzOCSMRz
# 5              46165                              Logistics  rvdxnecKX3y
# 6              46166                          Environmental  C4ToS1lYxV4
# 7              82259                              HIV tests  quxsURVhvlw
# 8              93709                Family Planning Methods  kGdVbkdUzdl
# 9              93710             Family Planning Attendance  jfDnGFOMhHA
# 10             93808  FP Commodities Couple Year Protection  YUgK6HcT79P
# 11             93809               FP Commodities DIspensed  qQrGvRPfU9v
# 12             94763          FP Commodities Ending Balance  EVdmyCqaRuV
# 13             96876                          IP Ward Level  F0KmwJQdQ05
# 14            101922                    Malaria Commodities  t0UQvqyJw19
# 15             35441                         Human Resource  cscsrlXYiOB
# 16            179040                             Population  foNgmbVZNIB
# 17             35442                         MOH731-2 PMTCT  lBD0xqWqgqi
# 18             35444                            TB Services  mVgPQPypBUb
# 19            274285                         Community Unit  JAZ4pl451fQ
# 20            276489                Hospital Administrative  NfpY4dDnNKH
# 21             31590                          Safe Delivery  aLAsX2SDTL2
# 22             35440                        Family Planning  aHA4B9Ubgec
# 23             31721                              Antenatal  ILjnvZREKIe
# 24            307888      Malaria Early Warning Data (MEWs)  bbObIZnDVGa
# 25             31722                                Malaria  BO988GSyf0X
# 26            342076                    Ophthalmic Services  rwAsLJC6Dmq
# 27            393335                              Inpatient  N3UGYnhqhM4
# 28             21025                            Out Patient  ji8qxM6Z9Pm
# 29            412883                           PMTCT_NASCOP  ly1jzPSOn2X
# 30            413029                            HTC-MOH 711  s1Q2w1R9Owj
# 31             21024                           Immunisation  mwndwamx3WU
# 32           2449465                             EAC OHI DE  GHNwcpeNXm0
# 40  None 2015-08-12 08:41:13.350 2015-08-11 08:16:13.399  276592.0
#
#    publicaccess _datecreated _eventexecutionkey _lastaction _mergekey  \
# 0      rw------         None               None        None      None
# 1          None         None               None        None      None
# 2      rw------         None               None        None      None
# 3      rw------         None               None        None      None
# 4          None         None               None        None      None
# 5          None         None               None        None      None
# 6          None         None               None        None      None
# 7          None         None               None        None      None
# 8          None         None               None        None      None
# 9          None         None               None        None      None
# 10         None         None               None        None      None
# 11         None         None               None        None      None
# 12         None         None               None        None      None
# 13         None         None               None        None      None
# 14         None         None               None        None      None
# 15         None         None               None        None      None
# 16         None         None               None        None      None
# 17         None         None               None        None      None
# 18         None         None               None        None      None
# 19         None         None               None        None      None
# 20         None         None               None        None      None
# 21         None         None               None        None      None
# 22         None         None               None        None      None
# 23         None         None               None        None      None
# 24         None         None               None        None      None
# 25         None         None               None        None      None
# 26         None         None               None        None      None
# 27     rw------         None               None        None      None
# 28         None         None               None        None      None
# 29     rw------         None               None        None      None
# 30     rw------         None               None        None      None
# 31         None         None               None        None      None
# 32         None         None               None        None      None
# 33         None         None               None        None      None
# 34         None         None               None        None      None
# 35         None         None               None        None      None
# 36         None         None               None        None      None
# 37         None         None               None        None      None
# 38         None         None               None        None      None
# 39         None         None               None        None      None
# 40     rw------         None               None        None      None
#
#    _sourcesystemcode
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# 5               None
# 6               None
# 7               None
# 8               None
# 9               None
# 10              None
# 11              None
# 12              None
# 13              None
# 14              None
# 15              None
# 16              None
# 17              None
# 18              None
# 19              None
# 20              None
# 21              None
# 22              None
# 23              None
# 24              None
# 25              None
# 26              None
# 27              None
# 28              None
# 29              None
# 30              None
# 31              None
# 32              None
# 33              None
# 34              None
# 35              None
# 36              None
# 37              None
# 38              None
# 39              None
# 40              None

# %%
def get_indicator_group_by_id(indicator_group_id):
    '''return a single indicator group matching the id'''
    conn = get_connection()
    
    all_indicator_groups = DataFrame()
    
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_indicatorgroup', con=conn, chunksize=100):
        all_indicator_groups = all_indicator_groups.append(chunk)
    
    single_indicator = all_indicator_groups[all_indicator_groups['indicatorgroupid']==indicator_group_id]
    return single_indicator

# %%
get_indicator_group_by_id(412980)
# Out:
#    indicatorgroupid                            name          uid  code  \
# 0            412980  HIV care and treatment-MOH 711  Ym44sNLgAnM  None
#
#               lastupdated                 created   userid publicaccess  \
# 0 2013-07-19 11:35:44.396 2013-07-18 10:16:32.443  24850.0     rw------
#
#   _datecreated _eventexecutionkey _lastaction _mergekey _sourcesystemcode
# 0         None               None        None      None              None

# %%
def get_all_indicator_group_members():
    '''return all indicators in an indicator group'''
    conn = get_connection()    
    
    all_indicator_group_members = DataFrame()
    
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_indicatorgroupmembers', con=conn, chunksize=100):
        all_indicator_group_members = all_indicator_group_members.append(chunk)        
    
    return all_indicator_group_members

# %%
get_all_indicator_group_members()
# Out:
#     indicatorid  indicatorgroupid _datecreated _eventexecutionkey _lastaction  \
# 65      None              None
#
# [666 rows x 7 columns]

# %%
def get_indicator_group_members(indicator_group_id):
    '''return all indicators in an indicator group'''
    conn = get_connection()
    
    #get the indicator group
    indicator_group = get_indicator_group_by_id(indicator_group_id)
    indicator_group = indicator_group.rename(index=str, columns={'name': 'indicator_group_name'})
    
    all_indicator_group_members = DataFrame()
    
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_indicatorgroupmembers', con=conn, chunksize=100):
        all_indicator_group_members = all_indicator_group_members.append(chunk)
    
    indicator_group_members = pd.merge(all_indicator_group_members, indicator_group, on='indicatorgroupid')
    
    return indicator_group_members

# %%
get_indicator_group_members(412980).columns
# Out:
# Index([u'indicatorid', u'indicatorgroupid', u'_datecreated_x',
#        u'_eventexecutionkey_x', u'_lastaction_x', u'_mergekey_x',
#        u'_sourcesystemcode_x', u'indicator_group_name', u'uid', u'code',
#        u'lastupdated', u'created', u'userid', u'publicaccess',
#        u'_datecreated_y', u'_eventexecutionkey_y', u'_lastaction_y',
#        u'_mergekey_y', u'_sourcesystemcode_y'],
#       dtype='object')

# %%
def get_indicator_group_indicators(indicator_group_id):
    '''get all indicators in an indicator group'''
    conn=get_connection()
    #get indicator memmbers
    indicator_memmber = get_indicator_group_members(indicator_group_id)
    
    all_indicators = DataFrame()
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_indicator', con=conn, chunksize=100):
        all_indicators = all_indicators.append(chunk)
    
    indicators = pd.merge(all_indicators, indicator_memmber, on='indicatorid')
    
    
    return indicators

# %%
# get_indicator_group_indicators(84109).dtypes
print get_indicator_group_indicators(412980)[['numerator']]
# Out:
#                                            numerator
# 0                      #{qa1IrxISrSJ}+#{qMybCnYBkNY}
# 1  #{cTY2tTKwUqd}+#{eNcsljfoUKW}+#{jFrSw8UkNQ4}+#...
# 2  #{cTY2tTKwUqd}+#{eNcsljfoUKW}+#{jFrSw8UkNQ4}+#...
# 3  #{kMe8cor2UxQ.j03wX0lCHZc}+#{kMe8cor2UxQ.vVket...
# 4  #{dnNfHX89udH}+#{C8ZgpIWef1p}+#{k8Y2rcga2FJ}+#...
# 5  #{cTY2tTKwUqd}+#{eNcsljfoUKW}+#{jFrSw8UkNQ4}+#...
# 6  #{dnNfHX89udH}+#{C8ZgpIWef1p}+#{k8Y2rcga2FJ}+#...

# %%
def get_indicator_by_id(indicator_id):
    '''get specific indicator by id'''
    conn=get_connection()
    
    query = "SELECT * FROM dim_dhis_indicator WHERE indicatorid = '%s';" %(indicator_id)
    indicator = pd.read_sql(query, conn)
    
    return indicator

# %%
get_indicator_by_id(413098)
# Out:
#    indicatorid                               indicatorname      shortname  \
# 0       413098  Total number of patients currently on ARVs  Total on ARVs
#
#    code                                        description  annualized  \
# 0  None  All patients currently on ARVs(pregnant women ...       False
#
#    indicatortypeid indicatortypename  indicatortypefactor  \
# 0            23696            Number                    1
#
#    indicatortypenumber        ...        denominator denominatordescription  \
# 0                 True        ...                  1                      1
#
#     uid           denominatorsql  \
# 0  None  SELECT 1 as denominator
#
#                                         numeratorsql _datecreated  \
# 0  SELECT value1+value2 as numerator FROM  (SELEC...   2016-02-01
#
#   _eventexecutionkey _lastaction _mergekey _sourcesystemcode
# 0               None           I      None              None
#
# [1 rows x 23 columns]

# %%
def get_dataelment_by_id(dataelement_id):
    '''get specific data element'''
    conn=get_connection()
    #get data element
    
    all_dataelements = DataFrame()
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_dataelement', con=conn, chunksize=10000):
        all_dataelements = all_dataelements.append(chunk)
       
    return all_dataelements

# %%
de = get_dataelment_by_id('qa1IrxISrSJ')

# %%
#get a specific county
def get_category_combos():
    conn = get_connection()
    all_orgunits = pd.DataFrame()
    for chunk in pd.read_sql('SELECT * FROM dim_dhis_categoryoptioncombo', con=conn, chunksize=10000):
        all_orgunits = all_orgunits.append(chunk)
    
    return all_orgunits

# %%
get_category_combos()
# Out:
#       categoryoptioncomboid          uid  code _datecreated  \
# 0                   8688567  r6zTEVft9H1  None         None
# 1                   8813495  lZUIAg6whIT  None         None
# 2                   8813496  xBF0SZh6k2f  None         None
# 3                   8813497  ejejj1FVTq2  None         None
# 4                   8813498  XzPlCAJe8jX  None         None
# 5                     20673  ieuodyY5ybC  None         None
# 6                     20674  bCfwecaPx2W  None         None
# 7                     20676  lHl2rmXpHse  None         None
# 8                     20677  SeDaCnHi3m5  None         None
# 9                     21258  omEDL5LVgDJ  None         None
# 10                    21259  g6112VF7T29  None         None
# 11                    21260  j03wX0lCHZc  None         None
# 12                    21261  vVketPHJwSY  None         None
# 13                    21268  wBWcFk7k1qY  None         None
# 14                    21325  sXgcr8o6TqL  None         None
# 15                    21615  Lj5arkL7GL8  None         None
# 16                    21616  ObiJr399QRt  None         None
# 17                    21617  bPNw3Km3Ug7  None         None
# 18                    21618  JUI7tesx6as  None         None
# 19                    21683  U4pOspYgS6C  None         None
# 20                    21684  BhEifF7qaMa  None         None
# 21                    21685  E001TwZacAM  None         None
# 22                    21686  UcbjkmT8m0e  None         None
# 23                    21687  PyfuYO3qlk2  None         None
# 24                    21688  uyHMrgHkWa4  None         None
# 25                    21689  K4bGFMZEuMW  None         None
# 26                    21690  cSmXmzTMZDN  None         None
# 27                   261754  WDafWKWrI84  None         None
# 28                   261755  XIQ1SeOshtt  None         None
# 29                   261756  RYmHjCLU2CB  None         None
# ...                     ...          ...   ...          ...
# 993                 7839686  JRPzrvKWxIU  None         None
# 994                 7839687  ZnAiy4Avkoo  None         None
# 995                 7839688  A6AJd72OBem  None         None
# 996                 7839689  Hd6rg3KwxWe  None         None
# 997                 7839690  Mn2LAHnCBHT  None         None
# 998                 7839691  py8ArdZAgVA  None         None
# 999                 7839692  qPTIGNYhKcP  None         None
# 1000                7839693  qVM5nQVj5Ll  None         None
# 1001                7839694  k4Xh1PG3s66  None         None
# 1002                7839695  KBOCcfnNK1v  None         None
# 1003                7839696  xDofrBdn4XL  None         None
# 1004                7839697  olBzxhSMSuU  None         None
# 1005                7839698  SPE6IGh6XHv  None         None
# 1006                7839699  fPke0YL2TaI  None         None
# 1007                7839700  Zq6Muz8NQkt  None         None
# 1008                7839701  YP4rvjo8uzQ  None         None
# 1009                7839702  lfvCtV9GtmS  None         None
# 1010                7839703  j3ojMzPeuvb  None         None
# 1011                7839704  mLrXxQcKIYb  None         None
# 1012                7839705  p8cYhLPM85h  None         None
# 1013                7839706  Q2fJIoTjXmH  None         None
# 1014                7839707  uNMs41JK2j7  None         None
# 1015                7839708  X6j2oNQnPbP  None         None
# 1016                7839709  fr6IsBGWBij  None         None
# 1017                7839710  XYV3G9dNBO2  None         None
# 1018                7839711  tcILlX0W3if  None         None
# 1019                7839712  zEgbDqlud0x  None         None
# 1020                7839713  zJC3RpA15eu  None         None
# 1021                7839714  WnziS9vmokE  None         None
# 1022                7839715  VCjhEgPZNU1  None         None
#
#      _eventexecutionkey _lastaction _mergekey _sourcesystemcode
# 0                  None        None      None              None
# 1                  None        None      None              None
# 2                  None        None      None              None
# 3                  None        None      None              None
# 4                  None        None      None              None
# 5                  None        None      None              None
# 6                  None        None      None              None
# 7                  None        None      None              None
# 8                  None        None      None              None
# 9                  None        None      None              None
# 10                 None        None      None              None
# 11                 None        None      None              None
# 12                 None        None      None              None
# 13                 None        None      None              None
# 14                 None        None      None              None
# 15                 None        None      None              None
# 16                 None        None      None              None
# 17                 None        None      None              None
# 18                 None        None      None              None
# 19                 None        None      None              None
# 20                 None        None      None              None
# 21                 None        None      None              None
# 22                 None        None      None              None
# 23                 None        None      None              None
# 24                 None        None      None              None
# 25                 None        None      None              None
# 26                 None        None      None              None
# 27                 None        None      None              None
# 28                 None        None      None              None
# 29                 None        None      None              None
# ...                 ...         ...       ...               ...
# 993                None        None      None              None
# 994                None        None      None              None
# 995                None        None      None              None
# 996                None        None      None              None
# 997                None        None      None              None
# 998                None        None      None              None
# 999                None        None      None              None
# 1000               None        None      None              None
# 1001               None        None      None              None
# 1002               None        None      None              None
# 1003               None        None      None              None
# 1004               None        None      None              None
# 1005               None        None      None              None
# 1006               None        None      None              None
# 1007               None        None      None              None
# 1008               None        None      None              None
# 1009               None        None      None              None
# 1010               None        None      None              None
# 1011               None        None      None              None
# 1012               None        None      None              None
# 1013               None        None      None              None
# 1014               None        None      None              None
# 1015               None        None      None              None
# 1016               None        None      None              None
# 1017               None        None      None              None
# 1018               None        None      None              None
# 1019               None        None      None              None
# 1020               None        None      None              None
# 1021               None        None      None              None
# 1022               None        None      None              None
#
# [1023 rows x 8 columns]

# %%
def get_category_option_combo_by_uid(category_option_combo_id):
    conn = get_connection()
    all_category_option_combos = pd.DataFrame()
    query =  '''SELECT * 
                FROM dim_dhis_categoryoptioncombo
                WHERE uid = '%s'
            ''' %(category_option_combo_id)
    all_category_option_combos =  pd.read_sql(query, con=conn)
        
    
    return all_category_option_combos

# %%
get_category_option_combo_by_uid('NhSoXUMPK2K')
# Out:
#    categoryoptioncomboid          uid  code _datecreated _eventexecutionkey  \
# 0                     15  NhSoXUMPK2K  None         None               None
#
#   _lastaction _mergekey _sourcesystemcode
# 0        None      None              None

# %%
def get_period_details(period_id, in_json=False):
    ''' return period id details'''
    conn = get_connection()
    all_periods = pd.DataFrame()
    query = "SELECT * FROM dim_dhis_period WHERE periodid = %s ;" %(period_id)
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_periods = all_periods.append(chunk)
    
    return all_periods

# %%
periods =get_period_details(2506122, False)
periods
# Out:
#    periodid  periodtypeid periodtypename   startdate     enddate _datecreated  \
# 0   2506122             5        Monthly  2015-03-01  2015-03-31         None
#
#   _eventexecutionkey _lastaction _mergekey _sourcesystemcode yearmonth
# 0               None        None      None              None    2015 3

# %%
#get period ids from year
def get_year_periods(year_id):
    '''return all periods in the year specified '''
    conn = get_connection()
    all_periods = DataFrame()
    #query = "SELECT * FROM dim_dhis_period WHERE yearmonth LIKE"
    query = "SELECT * FROM dim_dhis_period WHERE yearmonth @@ to_tsquery('%s')" %(year_id)
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_periods = all_periods.append(chunk)
    
    all_periods['year'] = all_periods['yearmonth'].str.split(' ').str[1]
    all_periods['month'] = all_periods['yearmonth'].str.split(' ').str[2]
    return all_periods

# %%
get_year_periods(2015)
# Out:
#      periodid  periodtypeid periodtypename   startdate     enddate  \
# 0      304112             8         Yearly  2015-01-01  2015-12-31
# 1      227750         45616  FinancialJuly  2015-07-01  2016-06-30
# 2     2505073             5        Monthly  2015-04-01  2015-04-30
# 3     2506122             5        Monthly  2015-03-01  2015-03-31
# 4     2890974             5        Monthly  2015-06-01  2015-06-30
# 5     2890978             5        Monthly  2015-01-01  2015-01-31
# 6     2890979             5        Monthly  2015-02-01  2015-02-28
# 7     2890980             5        Monthly  2015-05-01  2015-05-31
# 8     3992158             5        Monthly  2015-10-01  2015-10-31
# 9     4588510             5        Monthly  2015-11-01  2015-11-30
# 10    4770037             6      Quarterly  2015-10-01  2015-12-31
# 11    4770038             6      Quarterly  2015-01-01  2015-03-31
# 12    4839357             6      Quarterly  2015-07-01  2015-09-30
# 13    4839358             6      Quarterly  2015-04-01  2015-06-30
# 14    4885141             3          Daily  2015-01-06  2015-01-06
# 15    4901930             5        Monthly  2015-12-01  2015-12-31
# 16    4938353             3          Daily  2015-01-08  2015-01-08
# 17    4946897             3          Daily  2015-01-09  2015-01-09
# 18    4946904             3          Daily  2015-01-07  2015-01-07
# 19    4946909             3          Daily  2015-01-05  2015-01-05
# 20    4946911             3          Daily  2015-01-04  2015-01-04
# 21    4946915             3          Daily  2015-01-03  2015-01-03
# 22    4946916             3          Daily  2015-01-02  2015-01-02
# 23    4946920             3          Daily  2015-01-01  2015-01-01
# 24    4969762             4         Weekly  2015-01-05  2015-01-11
# 25    4969990             4         Weekly  2015-01-12  2015-01-18
# 26    4990265             3          Daily  2015-01-10  2015-01-10
# 27    4990266             3          Daily  2015-01-11  2015-01-11
# 28    5001540             7     SixMonthly  2015-01-01  2015-06-30
# 29    5055618             3          Daily  2015-01-13  2015-01-13
# ..        ...           ...            ...         ...         ...
# 260   8681318             3          Daily  2015-07-23  2015-07-23
# 261   8688385             3          Daily  2015-07-25  2015-07-25
# 279         None               None        None      None              None
# 280         None               None        None      None              None
# 281         None               None        None      None              None
# 282         None               None        None      None              None
# 283         None               None        None      None              None
# 284         None               None        None      None              None
# 285         None               None        None      None              None
# 286         None               None        None      None              None
# 287         None               None        None      None              None
# 288         None               None        None      None              None
# 289         None               None        None      None              None
#
#     yearmonth  year month
# 0      2015 1  2015     1
# 1      2015 7  2015     7
# 2      2015 4  2015     4
# 3      2015 3  2015     3
# 4      2015 6  2015     6
# 5      2015 1  2015     1
# 6      2015 2  2015     2
# 7      2015 5  2015     5
# 8     2015 10  2015    10
# 9     2015 11  2015    11
# 10    2015 10  2015    10
# 11     2015 1  2015     1
# 12     2015 7  2015     7
# 13     2015 4  2015     4
# 14     2015 1  2015     1
# 15    2015 12  2015    12
# 16     2015 1  2015     1
# 17     2015 1  2015     1
# 18     2015 1  2015     1
# 19     2015 1  2015     1
# 20     2015 1  2015     1
# 21     2015 1  2015     1
# 22     2015 1  2015     1
# 23     2015 1  2015     1
# 24     2015 1  2015     1
# 25     2015 1  2015     1
# 26     2015 1  2015     1
# 27     2015 1  2015     1
# 28     2015 1  2015     1
# 29     2015 1  2015     1
# ..        ...   ...   ...
# 260    2015 7  2015     7
# 261    2015 7  2015     7
# 262    2015 7  2015     7
# 263    2015 7  2015     7
# 264    2015 7  2015     7
# 265    2015 7  2015     7
# 266    2015 7  2015     7
# 267    2015 7  2015     7
# 268    2015 7  2015     7
# 269    2015 7  2015     7
# 270    2015 7  2015     7
# 271    2015 7  2015     7
# 272    2015 7  2015     7
# 273    2015 7  2015     7
# 274    2015 7  2015     7
# 275    2015 8  2015     8
# 276   2015 12  2015    12
# 277    2015 8  2015     8
# 278    2015 7  2015     7
# 279    2015 8  2015     8
# 280    2015 8  2015     8
# 281    2015 8  2015     8
# 282    2015 8  2015     8
# 283    2015 8  2015     8
# 284    2015 8  2015     8
# 285    2015 8  2015     8
# 286    2015 8  2015     8
# 287    2015 8  2015     8
# 288    2015 8  2015     8
# 289    2015 8  2015     8
#
# [290 rows x 13 columns]

# %%
#get period ids from year
def get_year_periodtypes(year_id, period_type_id):
    '''return all periods in the year specified '''
    conn = get_connection()
    all_periods = DataFrame()
    #query = "SELECT * FROM dim_dhis_period WHERE yearmonth LIKE"
    query = "SELECT * FROM dim_dhis_period WHERE yearmonth @@ to_tsquery('%s') AND periodtypeid = '%s'" %(year_id,period_type_id)
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_periods = all_periods.append(chunk)
    
    all_periods['year'] = all_periods['yearmonth'].str.split(' ').str[1]
    all_periods['month'] = all_periods['yearmonth'].str.split(' ').str[2]
    return all_periods

# %%
get_year_periodtypes(2014,5)
# Out:
#     periodid  periodtypeid periodtypename   startdate     enddate  \
# 0     723795             5        Monthly  2014-12-01  2014-12-31
# 1     723879             5        Monthly  2014-10-01  2014-10-31
# 2    1114558             5        Monthly  2014-01-01  2014-01-31
# 3    1185013             5        Monthly  2014-02-01  2014-02-28
# 4    1185014             5        Monthly  2014-03-01  2014-03-31
# 5    1185015             5        Monthly  2014-04-01  2014-04-30
# 6    1185016             5        Monthly  2014-05-01  2014-05-31
# 7    1185017             5        Monthly  2014-06-01  2014-06-30
# 8    1185018             5        Monthly  2014-07-01  2014-07-31
# 9    1185019             5        Monthly  2014-08-01  2014-08-31
# 10   1185020             5        Monthly  2014-09-01  2014-09-30
# 11   1185021             5        Monthly  2014-11-01  2014-11-30
#
#    _datecreated _eventexecutionkey _lastaction _mergekey _sourcesystemcode  \
# 0          None               None        None      None              None
# 1          None               None        None      None              None
# 2          None               None        None      None              None
# 3          None               None        None      None              None
# 4          None               None        None      None              None
# 5          None               None        None      None              None
# 6          None               None        None      None              None
# 7          None               None        None      None              None
# 8          None               None        None      None              None
# 9          None               None        None      None              None
# 10         None               None        None      None              None
# 11         None               None        None      None              None
#
#    yearmonth  year month
# 0    2014 12  2014    12
# 1    2014 10  2014    10
# 2     2014 1  2014     1
# 3     2014 2  2014     2
# 4     2014 3  2014     3
# 5     2014 4  2014     4
# 6     2014 5  2014     5
# 7     2014 6  2014     6
# 8     2014 7  2014     7
# 9     2014 8  2014     8
# 10    2014 9  2014     9
# 11   2014 11  2014    11

# %%
#get period ids from year
def get_year_month_periods(year, month):
    '''return all periods in the year specified '''
    conn = get_connection()
    all_periods = DataFrame()
    #query = "SELECT * FROM dim_dhis_period WHERE yearmonth LIKE"
    query = "SELECT * FROM dim_dhis_period WHERE yearmonth @@ to_tsquery('%s &%s')" %(year, month)    
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_periods = all_periods.append(chunk)
    
    return all_periods

# %%
get_year_month_periods(2015,1)
# Out:
#     periodid  periodtypeid periodtypename   startdate     enddate  \
# 0     304112             8         Yearly  2015-01-01  2015-12-31
# 1    2890978             5        Monthly  2015-01-01  2015-01-31
# 2    4770038             6      Quarterly  2015-01-01  2015-03-31
# 3    4885141             3          Daily  2015-01-06  2015-01-06
# 4    4938353             3          Daily  2015-01-08  2015-01-08
# 5    4946897             3          Daily  2015-01-09  2015-01-09
# 6    4946904             3          Daily  2015-01-07  2015-01-07
# 7    4946909             3          Daily  2015-01-05  2015-01-05
# 8    4946911             3          Daily  2015-01-04  2015-01-04
# 9    4946915             3          Daily  2015-01-03  2015-01-03
# 10   4946916             3          Daily  2015-01-02  2015-01-02
# 11   4946920             3          Daily  2015-01-01  2015-01-01
# 12   4969762             4         Weekly  2015-01-05  2015-01-11
# 13   4969990             4         Weekly  2015-01-12  2015-01-18
# 14   4990265             3          Daily  2015-01-10  2015-01-10
# 15   4990266             3          Daily  2015-01-11  2015-01-11
# 16   5001540             7     SixMonthly  2015-01-01  2015-06-30
# 17   5055618             3          Daily  2015-01-13  2015-01-13
# 18   5087196             3          Daily  2015-01-15  2015-01-15
# 19   5108155             3          Daily  2015-01-14  2015-01-14
# 20   5155063             3          Daily  2015-01-19  2015-01-19
# 21   5176570             3          Daily  2015-01-12  2015-01-12
# 22   5176572             3          Daily  2015-01-16  2015-01-16
# 23   5176573             3          Daily  2015-01-17  2015-01-17
# 24   5176574             3          Daily  2015-01-18  2015-01-18
# 25   5176576             3          Daily  2015-01-20  2015-01-20
# 26   5236450             4         Weekly  2015-01-19  2015-01-25
# 27   5256650             3          Daily  2015-01-21  2015-01-21
# 28   5278559         89687      BiMonthly  2015-01-01  2015-02-28
# 29   5392159             4         Weekly  2015-01-26  2015-02-01
# 30   5413345             3          Daily  2015-01-27  2015-01-27
# 31   5567829             3          Daily  2015-01-28  2015-01-28
# 32   5679434             3          Daily  2015-01-30  2015-01-30
# 33   5680616             3          Daily  2015-01-29  2015-01-29
# 34   5682937             3          Daily  2015-01-31  2015-01-31
# 35   5682938             3          Daily  2015-01-26  2015-01-26
# 36   5682939             3          Daily  2015-01-25  2015-01-25
# 37   5682940             3          Daily  2015-01-24  2015-01-24
# 38   5682941             3          Daily  2015-01-23  2015-01-23
# 39   5682942             3          Daily  2015-01-22  2015-01-22
#
#    _datecreated _eventexecutionkey _lastaction _mergekey _sourcesystemcode  \
# 0          None               None        None      None              None
# 1          None               None        None      None              None
# 2          None               None        None      None              None
# 3          None               None        None      None              None
# 4          None               None        None      None              None
# 5          None               None        None      None              None
# 6          None               None        None      None              None
# 7          None               None        None      None              None
# 8          None               None        None      None              None
# 9          None               None        None      None              None
# 10         None               None        None      None              None
# 11         None               None        None      None              None
# 12         None               None        None      None              None
# 13         None               None        None      None              None
# 14         None               None        None      None              None
# 15         None               None        None      None              None
# 16         None               None        None      None              None
# 17         None               None        None      None              None
# 18         None               None        None      None              None
# 19         None               None        None      None              None
# 20         None               None        None      None              None
# 21         None               None        None      None              None
# 22         None               None        None      None              None
# 23         None               None        None      None              None
# 24         None               None        None      None              None
# 25         None               None        None      None              None
# 26         None               None        None      None              None
# 27         None               None        None      None              None
# 28         None               None        None      None              None
# 29         None               None        None      None              None
# 30         None               None        None      None              None
# 31         None               None        None      None              None
# 32         None               None        None      None              None
# 33         None               None        None      None              None
# 34         None               None        None      None              None
# 35         None               None        None      None              None
# 36         None               None        None      None              None
# 37         None               None        None      None              None
# 38         None               None        None      None              None
# 39         None               None        None      None              None
#
#    yearmonth
# 0     2015 1
# 1     2015 1
# 2     2015 1
# 3     2015 1
# 4     2015 1
# 5     2015 1
# 6     2015 1
# 7     2015 1
# 8     2015 1
# 9     2015 1
# 10    2015 1
# 11    2015 1
# 12    2015 1
# 13    2015 1
# 14    2015 1
# 15    2015 1
# 16    2015 1
# 17    2015 1
# 18    2015 1
# 19    2015 1
# 20    2015 1
# 21    2015 1
# 22    2015 1
# 23    2015 1
# 24    2015 1
# 25    2015 1
# 26    2015 1
# 27    2015 1
# 28    2015 1
# 29    2015 1
# 30    2015 1
# 31    2015 1
# 32    2015 1
# 33    2015 1
# 34    2015 1
# 35    2015 1
# 36    2015 1
# 37    2015 1
# 38    2015 1
# 39    2015 1

# %%
#get a specific facility
def get_facility_by_id(facility_id):
    conn = get_connection()
    all_facilities = pd.DataFrame()
    query = "SELECT * FROM facilities_facility WHERE id = '%s' ;" %(facility_id)    
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_facilities = all_facilities.append(chunk)

    
    return all_facilities

# %%
get_facility_by_id("da850a5f-df4e-4650-b950-2f86839748f7")
# Out:
#                                      id  deleted  active                name  \
# 0  da850a5f-df4e-4650-b950-2f86839748f7    False    True  St Monica Hospital
#
#         official_name   code registration_number abbreviation description  \
# 0  St Monica Hospital  14120                None         None        None
#
#    number_of_beds     ...       _effectivefrom  _effectiveto  \
# 0             100     ...           1900-01-01    2199-12-31
#
#                                 ward_id                      facility_type_id  \
# 0  20a463b3-e899-4ef7-983e-b851ffc702c9  c24479c1-6088-44ec-8e47-79754089c0b6
#
#                           keph_level_id                              owner_id  \
# 0  415184b9-434a-44ae-b893-c1249df5d8b6  8cc87f18-aa70-4c86-afcc-173a7e6ba7ed
#
#    parent_id sub_county_id                               town_id  facility_sk
# 0       None          None  54a75215-92e2-40b4-99ce-fcd805eb21af         5678
#
# [1 rows x 48 columns]

# %%
def get_period_by_id(period_id):
    '''return all periods in the year specified '''
    conn = get_connection()
    all_periods = DataFrame()
    #query = "SELECT * FROM dim_dhis_period WHERE yearmonth LIKE"
    query = "SELECT * FROM dim_dhis_period WHERE periodid = %s" %(period_id)    
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_periods = all_periods.append(chunk)
    
    
    return all_periods

# %%
get_period_by_id(2505073)
# Out:
#    periodid  periodtypeid periodtypename   startdate     enddate _datecreated  \
# 0   2505073             5        Monthly  2015-04-01  2015-04-30         None
#
#   _eventexecutionkey _lastaction _mergekey _sourcesystemcode yearmonth
# 0               None        None      None              None    2015 4

# %%
def get_facility_org_units(facility_id):
    conn = get_connection()
    #get the facility    
    query = ''' SELECT  a.organisationunitid, a.code, b.name
                FROM dim_dhis_organisationunit a , facilities_facility b
                WHERE a.code = CAST(b.code as VarChar) AND b.id = '%s' ''' %(facility_id)
    
    facility_orgunit = pd.read_sql(query,conn)
    
    return facility_orgunit

# %%
get_facility_org_units("da850a5f-df4e-4650-b950-2f86839748f7")
# Out:
#    organisationunitid   code                name
# 0               24726  14120  St Monica Hospital

# %%
#get period ids from year
def get_facility_indicator_calculated_valued():
    '''return all indicator values  '''
    conn = get_connection()
    all_indicator_values = DataFrame()
    
    query = "select * from fact_dhis_indicatorcalculatedvalues limit 100000;"
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_indicator_values = all_indicator_values.append(chunk)
    
    return all_indicator_values

# %%
ind = get_facility_indicator_calculated_valued()

# %%
def get_period_types():
    '''return all period types'''
    conn = get_connection()
    all_period_types = DataFrame()
    
    query = "select DISTINCT(periodtypename) as name, periodtypeid as id  from dim_dhis_period;"
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_period_types = all_period_types.append(chunk)
    
    return all_period_types

# %%
get_period_types()
# Out:
#                name       id
# 0      FinancialOct    45617
# 1           Monthly        5
# 2        SixMonthly        7
# 3            Yearly        8
# 4    FinancialApril    39627
# 5         Quarterly        6
# 6            Weekly        4
# 7     FinancialJuly    45616
# 8         BiMonthly    89687
# 9   SixMonthlyApril  3993294
# 10            Daily        3

# %%
def get_indicator_values(indicator_id, facility_id, period_id):
    '''return all period types'''
    conn = get_connection()
    all_period_types = DataFrame()
    
    query = "select DISTINCT(periodtypename) as name, periodtypeid as id  from dim_dhis_period;"
    for chunk in pd.read_sql(query, con=conn, chunksize=10000):
        all_period_types = all_period_types.append(chunk)
    
    return all_period_types

# %%
def get_facility_dataelement_datavalues(dataelement_id, source_id, period_id):
    conn = get_connection()
    all_datavalues = DataFrame()
    
    query = ''' SELECT a.* 
                FROM fact_dhis_datavalue a , dim_dhis_dataelement b
                WHERE a.dataelementid = b.dataelementid
                AND b.uid = '%s' 
                AND a.sourceid = %s 
                AND a.periodid = '%s'; ''' %(dataelement_id, source_id, period_id)
    all_datavalues = pd.read_sql(query, con=conn )        
    
    return all_datavalues

# %%
get_facility_dataelement_datavalues('GCAkHwMAWM6','44911', '1185021')
# Out:
#    dataelementid  periodid  sourceid  categoryoptioncomboid  \
# 0          33731   1185021     44911                     15
#
#    attributeoptioncomboid value          storedby             lastupdated  \
# 0                      15     2  Gilbert Amburosi 2015-03-25 21:55:13.344
#
#   comment  followup                 created _datecreated _eventexecutionkey  \
# 0    None     False 2015-01-14 14:58:47.692   2015-12-17               None
#
#   _lastaction _mergekey _sourcesystemcode
# 0        None      None              None

# %%
def get_facility_dataelement_datavalues(dataelement_id, source_id, period_id, category_combo_id=None):
    conn = get_connection()
    all_datavalues = DataFrame()
    
    if category_combo_id:
        query = ''' SELECT a.* 
                    FROM fact_dhis_datavalue a , dim_dhis_dataelement b
                    WHERE a.dataelementid = b.dataelementid
                    AND b.uid = '%s' 
                    AND a.sourceid = %s 
                    AND a.periodid = '%s'
                    AND a.categoryoptioncomboid = '%s' ''' %(dataelement_id, source_id, period_id, category_combo_id)
    else:
        query = ''' SELECT a.* 
                FROM fact_dhis_datavalue a , dim_dhis_dataelement b
                WHERE a.dataelementid = b.dataelementid
                AND b.uid = '%s' 
                AND a.sourceid = %s 
                AND a.periodid = '%s'; ''' %(dataelement_id, source_id, period_id)
    all_datavalues = pd.read_sql(query, con=conn )        
    
    return all_datavalues

# %%
get_facility_dataelement_datavalues('TJMdle70A7X','44911', '723795', 15)
# Out:
# Empty DataFrame
# Columns: [dataelementid, periodid, sourceid, categoryoptioncomboid, attributeoptioncomboid, value, storedby, lastupdated, comment, followup, created, _datecreated, _eventexecutionkey, _lastaction, _mergekey, _sourcesystemcode]
# Index: []

# %%
def get_facility_category_datavalues(dataelement_id, source_id, period_id):
    conn = get_connection()
    all_datavalues = DataFrame()
    
    query = ''' SELECT a.* 
                FROM fact_dhis_datavalue a , dim_dhis_dataelement b
                WHERE a.dataelementid = b.dataelementid
                AND b.uid = '%s' 
                AND a.sourceid = %s 
                AND a.periodid = '%s'; ''' %(dataelement_id, source_id, period_id)
    all_datavalues = pd.read_sql(query, con=conn )        
    
    return all_datavalues

# %%
def get_indicator_values(facility_id, indicator_id, period_type, year ):
    conn = get_connection()
    indicator = get_indicator_by_id(indicator_id).loc[0]
    periods = get_year_periodtypes(year,period_type)
    facility = get_facility_org_units(facility_id).loc[0]
    results = []
    
    #define the pattern for dataelements-categorycombo and extract them
    pattern = "[a-zA-Z0-9]+\.[a-zA-Z0-9]+|[a-zA-Z0-9]+"
    numerator_dataelements = re.findall(pattern,indicator['numerator'])
    denominator_dataelements = re.findall(pattern,indicator['denominator'])

    
    #iterate through all periods
    for col, period in periods.iterrows():
        numerator = indicator['numerator'] 
        
        #iterate through dataelements 
        for datelement_category_combo in numerator_dataelements:           
            #extract the data element by searching for datalement. and replace with the id
            datelement= None
            
            # check if the dataelement has a category combo
            combo = re.findall("\.[a-zA-Z0-9]+", datelement_category_combo)
            
            if combo:
                #remove . in category combo expression and get uid
                combo = re.sub('\.','', combo[0])
                combo_uid = get_category_option_combo_by_uid(combo).loc[0]['categoryoptioncomboid']
                
                dataelement = re.sub('\.','' , re.findall("[a-zA-Z0-9]+\.", datelement_category_combo)[0]) 
                
            else:
                combo_uid = None
                dataelement = re.findall("[a-zA-Z0-9]+", datelement_category_combo)[0]

            value = get_facility_dataelement_datavalues(dataelement, facility['organisationunitid'], period['periodid'], combo_uid)

            if value.empty:            
                numerator = re.sub( "#{" + datelement_category_combo +"}" ,'0',numerator)                
            else:
                numerator = re.sub("#{" + datelement_category_combo +"}" ,value.loc[0]['value'],numerator)                
        numerator = float(eval(numerator))
        
        
        denominator = indicator['denominator']
        for datelement_category_combo in denominator_dataelements:                       
            datelement = None
            
            combo = re.findall("\.[a-zA-Z0-9]+", datelement_category_combo)
            if combo:
                combo = re.sub('\.','', combo[0])
                combo_uid = get_category_option_combo_by_uid(combo).loc[0]['categoryoptioncomboid']
                dataelement = re.sub('\.','' , re.findall("[a-zA-Z0-9]+\.", datelement_category_combo)[0]) 
            else:
                combo_uid = None
                dataelement = re.findall("[a-zA-Z0-9]+", datelement_category_combo)[0]

            value = get_facility_dataelement_datavalues(dataelement, facility['organisationunitid'], period['periodid'], combo_uid)
            if value.empty:      
                denominator = re.sub( "#{" + datelement_category_combo +"}" ,'1',denominator)                
            else:
                denominator = re.sub("#{" + datelement_category_combo +"}" ,value.loc[0]['value'],denominator)                
        denominator =  float(eval(denominator))
        indicator_value = {
            'indicator_id': indicator['indicatorid'],
            'value': (numerator/denominator),
            'year' : period['year'],
            'month': period['month']
        }
        
        results.append(indicator_value)
    
    return results

# %%
import time
start_time = time.time()
get_indicator_values('2e21b2de-7c5b-4db7-bb1d-26930af9274d',52912,5,2014)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.720944881439 seconds ---

# %%
get_indicator_values('2e21b2de-7c5b-4db7-bb1d-26930af9274d',52912,5,2014)
# Out:
# [{'indicator_id': 52912,
#   'month': '12',
#   'value': 0.07096774193548387,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '10',
#   'value': 0.053763440860215055,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '1',
#   'value': 0.047979797979797977,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '2',
#   'value': 0.05864197530864197,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '3',
#   'value': 0.0614406779661017,
#   'year': '2014'},
#  {'indicator_id': 52912, 'month': '4', 'value': 0.03125, 'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '5',
#   'value': 0.08181818181818182,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '6',
#   'value': 0.08361204013377926,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '7',
#   'value': 0.050505050505050504,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '8',
#   'value': 0.0784313725490196,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '9',
#   'value': 0.13812154696132597,
#   'year': '2014'},
#  {'indicator_id': 52912,
#   'month': '11',
#   'value': 0.0681265206812652,
#   'year': '2014'}]

# %%
def get_period_datavalues(facility,period, indicator, numerator_dataelements, denominator_dataelements ,results, index):
    numerator = indicator['numerator'] 
    
    #iterate through dataelements 
    for datelement_category_combo in numerator_dataelements:           
        #extract the data element by searching for datalement. and replace with the id
        datelement= None

        # check if the dataelement has a category combo
        combo = re.findall("\.[a-zA-Z0-9]+", datelement_category_combo)

        if combo:
            #remove . in category combo expression and get uid
            combo = re.sub('\.','', combo[0])
            combo_uid = get_category_option_combo_by_uid(combo).loc[0]['categoryoptioncomboid']

            dataelement = re.sub('\.','' , re.findall("[a-zA-Z0-9]+\.", datelement_category_combo)[0]) 
            
        else:
            combo_uid = None
            dataelement = re.findall("[a-zA-Z0-9]+", datelement_category_combo)[0]

        value = get_facility_dataelement_datavalues(dataelement, facility['organisationunitid'], period['periodid'], combo_uid)

        if value.empty:            
            numerator = re.sub( "#{" + datelement_category_combo +"}" ,'0',numerator)                
        else:
            numerator = re.sub("#{" + datelement_category_combo +"}" ,value.loc[0]['value'],numerator)                
    numerator = float(eval(numerator))


    denominator = indicator['denominator']
    for datelement_category_combo in denominator_dataelements:                       
        datelement = None

        combo = re.findall("\.[a-zA-Z0-9]+", datelement_category_combo)
        if combo:
            combo = re.sub('\.','', combo[0])
            combo_uid = get_category_option_combo_by_uid(combo).loc[0]['categoryoptioncomboid']
            dataelement = re.sub('\.','' , re.findall("[a-zA-Z0-9]+\.", datelement_category_combo)[0]) 
        else:
            combo_uid = None
            dataelement = re.findall("[a-zA-Z0-9]+", datelement_category_combo)[0]

        value = get_facility_dataelement_datavalues(dataelement, facility['organisationunitid'], period['periodid'], combo_uid)
        if value.empty:      
            denominator = re.sub( "#{" + datelement_category_combo +"}" ,'1',denominator)                
        else:
            denominator = re.sub("#{" + datelement_category_combo +"}" ,value.loc[0]['value'],denominator)                
    denominator =  float(eval(denominator))
    indicator_value = {
        'indicator_id': indicator['indicatorid'],
        'value': (numerator/denominator),
        'year' : period['year'],
        'month': period['month']
    }

    results.append(indicator_value)
        
    return results

# %%
def get_indicator_values2(facility_id, indicator_id, period_type, year ):
    from threading import Thread
    
    conn = get_connection()
    indicator = get_indicator_by_id(indicator_id).loc[0]
    periods = get_year_periodtypes(year,period_type)
    facility = get_facility_org_units(facility_id).loc[0]
    
    threads = [None] * len(periods.index)
    results = []
    
    #define the pattern for dataelements-categorycombo and extract them
    pattern = "[a-zA-Z0-9]+\.[a-zA-Z0-9]+|[a-zA-Z0-9]+"
    numerator_dataelements = re.findall(pattern,indicator['numerator'])
    denominator_dataelements = re.findall(pattern,indicator['denominator'])

    
    #iterate through all periods
    for col, period in periods.iterrows():
        threads[col] = Thread(target= get_period_datavalues, args=(facility, period, indicator, numerator_dataelements, denominator_dataelements, results, col))
        threads[col].start()

    for i in range(len(threads)):
        threads[i].join()
    return results

# %%
conn = get_connection()
# pd.read_sql( ('''Select * from dim_dhis_dataelement  where dataelementid = '%s' ''' %(33731)),  conn)
# pd.read_sql( ('''Select * from dim_dhis_dataelement  where uid = '%s' ''' %('qa1IrxISrSJ')),  conn)
# pd.read_sql( ('''Select * from dim_dhis_categoryoptioncombo  where uid = '%s' ''' %('NhSoXUMPK2K')),  conn)
# pd.read_sql( ('''select * from dim_dhis_period where periodid = '%s' ''' %(1185021)), conn)
# pd.read_sql( ('''select * from dim_dhis_period where periodtypeid = '%s' ''' %(4)), conn)
# pd.read_sql( '''select * from dim_dhis_period LIMIT 1000''', conn)
# pd.read_sql( ('''select * from dim_dhis_organisationunit where organisationunitid = '%s' ''' %(44911)), conn)
# pd.read_sql( ('''select * from facilities_facility where code = '%s' ''' %(15798)), conn)
# pd.read_sql( ('''select * from facilities_facility where id = '%s' ''' %("028d858c-c21d-4391-b4eb-7fea8ef0cb32")), conn)
pd.read_sql( (''' select * from dim_dhis_indicator where indicatorid =  '%s' '''%(413098)), conn)[['numerator']].to_json()
# pd.read_sql( ''' select * from dim_dhis_indicator ''', conn)[['denominator','indicatorid']]
# pd.read_sql( ''' select * from fact_dhis_datavalue LIMIT 1000  ''', conn)
# pd.read_sql( (''' select * from dim_dhis_ where indicatorid =  '%s' '''%(61829)), conn)
# Out:
# '{"numerator":{"0":"#{qa1IrxISrSJ}+#{qMybCnYBkNY}"}}'

# %%
pd.read_sql('SELECT * from fact_dhis_datavalue limit 1000',conn)
# Out:
#      dataelementid  periodid  sourceid  categoryoptioncomboid  \
# 0           510477   1185021     44751                 510530
# 1            21372   1185021     45114                  21315
# 2            20931   1185021     45161                  20673
# 3            23568   1185021     51442                     15
# 4            52575   1185021     45161                     15
# 5            79143   1185021     35549                     15
# 6            20921   1185021     45508                  20676
# 7            59580   1185021     32821                  21260
# 8           510548   1185021     32402                 510538
# 9            20914   1185021     39646                  20673
# 10           21627   1185021     32551                  21617
# 11           20931   1185021     39646                  20673
# 12           59941   1185021     35549                     15
# 13           33814   1185021     45201                     15
# 14           20950   1185021     35115                  20676
# 15           21397   1185021     45201                  21261
# 16           21241   1185021     31858                  21259
# 17          792266   1185021     45201                  20673
# 18           21487   1185021     39646                     15
# 19           20937   1185021     45201                  20673
# 20           21370   1185021     31858                  21259
# 21           20967   1185021     45201                  23581
# 22           21381   1185021     31858                  21316
# 23          164968   1185021     45201                  21315
# 24          100476    723879     35194                 100474
# 25           20955   1185021     50011                  20676
# 26           77843   1185021     45201                  21316
# 27          510459   1185021     32402                 510523
# 28          513960   1185021     39646                 513999
# 29           21587   1185021     45201                  21268
# ..             ...       ...       ...                    ...
# 970          21368   1185021     31851                  21260
# 971          21482   1185021     45114                     15
# 972          21388   1185021     45161                  21261
# 973         513960   1185021     61227                 513996
# 974         514004   1185021     45492                 513996
# 975         514008   1185021     45492                 514000
# 976          62012   1185021     45114                  21316
# 977          21375   1185021    122919                  21316
# 978          34029   1185021    404142                     15
# 979          21290   1185021     32708                     15
# 980          21295   1185021     32708                     15
# 981         513975   1185021     44459                 514000
# 982          21388   1185021    122919                  21260
# 983          34013   1185021    250801                     15
# 984         150387   1185021     80167                     15
# 985          21241   1185021     31868                  21260
# 986          21606   1185021     44459                     15
# 992   2015-12-17               None        None      None              None
# 993   2015-12-17               None        None      None              None
# 994   2015-12-17               None        None      None              None
# 995   2015-12-17               None        None      None              None
# 996   2015-12-17               None        None      None              None
# 997   2015-12-17               None        None      None              None
# 998   2015-12-17               None        None      None              None
# 999   2015-12-17               None        None      None              None
#
# [1000 rows x 16 columns]

# %%
indis = pd.read_sql("select * from dim_dhis_indicator ", get_connection())
indis[indis['numerator'].str.contains('GCAkHwMAWM6')]
# Series.unique(indis['indicatortypename'])
# Out:
#      indicatorid                                      indicatorname  \
# 373        61829                            PMTCT Positivity at ANC
# 712       477152  Total number of HIV-positive pregnant women in...
#
#                                  shortname  code  \
# 373                PMTCT Positivity at ANC  None
# 712  Total number of HIV-positive pregnant  None
#
#                                            description  annualized  \
# 373  ([HV02-05] + [HV02-06]) / [Integrated RH, HIVA...       False
# 712                                               None       False
#
#      indicatortypeid indicatortypename  indicatortypefactor  \
# 373            21017        Percentage                  100
# 712            23696            Number                    1
#
#      indicatortypenumber        ...                        denominator  \
# 373                False        ...         #{f9vesk5d4IY.NhSoXUMPK2K}
# 712                 True        ...                                  1
#
#               denominatordescription   uid  \
# 373  New ANC clients (ANC 1st Visit)  None
# 712                             None  None
#
#                                         denominatorsql  \
# 373  SELECT value1 as denominator FROM  (SELECT  CO...
# 712                            SELECT 1 as denominator
#
#                                           numeratorsql _datecreated  \
# 373  SELECT value1+value2 as numerator FROM  (SELEC...   2016-02-01
# 712  SELECT value1+value2 as numerator FROM  (SELEC...   2016-02-01
#
#     _eventexecutionkey _lastaction _mergekey _sourcesystemcode
# 373               None           I      None              None
# 712               None           I      None              None
#
# [2 rows x 23 columns]

# %%
periods = get_year_periodtypes(2014,7)[['year','month']]
    
periods
# Out:
#    year month
# 0  2014     1
# 1  2014     7

# %%
pd.read_sql('''select * from fact_dhis_datavalue  where fact_dhis_datavalue.dataelementid=21396  LIMIT 10000''', get_connection())
# Out:
#       dataelementid  periodid  sourceid  categoryoptioncomboid  \
# 0             21396   1185021     44751                  21260
# 1             21396   1185021     31868                  21260
# 2             21396   1185021     45161                  21260
# 3             21396   1185021     32426                  21260
# 4             21396   1185021     32830                  21260
# 5             21396   1185021    122919                  21260
# 6             21396   1185021     32815                  21260
# 7             21396   1185021     45114                  21260
# 8             21396   1185021     31847                  21260
# 9             21396   1185021     45200                  21260
# 10            21396   1185021     34393                  21260
# 11            21396   1185021     35318                  21260
# 12            21396   1185021     24726                  21260
# 13            21396   1185021     45058                  21260
# 14            21396   1185021     34369                  21260
# 15            21396   1185021     24721                  21260
# 16            21396   1185021     34392                  21260
# 17            21396   1185021     34389                  21260
# 18            21396   1185021     24546                  21260
# 19            21396   1185021     24719                  21260
# 20            21396   1185021     31911                  21260
# 21            21396   1185021     38262                  21260
# 22            21396   1185021     51451                  21260
# 23            21396   1185021     22702                  21260
# 24            21396   1185021     32564                  21260
# 25            21396   1185021     24539                  21260
# 26            21396   1185021     23334                  21260
# 27            21396   1185021     23331                  21260
# 28            21396   1185021     39558                  21260
# 9970   2015-12-17               None        None      None              None
# 9971   2015-12-17               None        None      None              None
# 9972   2015-12-17               None        None      None              None
# 9973   2015-12-17               None        None      None              None
# 9974   2015-12-17               None        None      None              None
# 9975   2015-12-17               None        None      None              None
# 9976   2015-12-17               None        None      None              None
# 9977   2015-12-17               None        None      None              None
# 9978   2015-12-17               None        None      None              None
# 9979   2015-12-17               None        None      None              None
# 9980   2015-12-17               None        None      None              None
# 9981   2015-12-17               None        None      None              None
# 9982   2015-12-17               None        None      None              None
# 9983   2015-12-17               None        None      None              None
# 9984   2015-12-17               None        None      None              None
# 9985   2015-12-17               None        None      None              None
# 9986   2015-12-17               None        None      None              None
# 9987   2015-12-17               None        None      None              None
# 9988   2015-12-17               None        None      None              None
# 9989   2015-12-17               None        None      None              None
# 9990   2015-12-17               None        None      None              None
# 9991   2015-12-17               None        None      None              None
# 9992   2015-12-17               None        None      None              None
# 9993   2015-12-17               None        None      None              None
# 9994   2015-12-17               None        None      None              None
# 9995   2015-12-17               None        None      None              None
# 9996   2015-12-17               None        None      None              None
# 9997   2015-12-17               None        None      None              None
# 9998   2015-12-17               None        None      None              None
# 9999   2015-12-17               None        None      None              None
#
# [10000 rows x 16 columns]

# %%
pd.read_sql(''' SELECT a.*
                    FROM fact_dhis_datavalue AS a , dim_dhis_dataelement b                    
                    WHERE  a.dataelementid = b.dataelementid
                    AND b.uid  = 'qa1IrxISrSJ' 
                    AND a.sourceid = '33707' 
                    AND a.periodid = '723795'
                    LIMIT 100''', get_connection())
# Out:
# Empty DataFrame
# Columns: [dataelementid, periodid, sourceid, categoryoptioncomboid, attributeoptioncomboid, value, storedby, lastupdated, comment, followup, created, _datecreated, _eventexecutionkey, _lastaction, _mergekey, _sourcesystemcode]
# Index: []

# %%
def get_facility_indicator_values_singlefetch(facility_id, indicator_id, period_type, year):
    conn = get_connection()
    indicator = get_indicator_by_id(indicator_id).loc[0]
    periods = get_year_periodtypes(year,period_type)
    facility = get_facility_org_units(facility_id).loc[0]
    results = []
    
    #define the pattern for dataelements-categorycombo and extract them
    pattern = "[a-zA-Z0-9]+\.[a-zA-Z0-9]+|[a-zA-Z0-9]+"
    numerator_formula = indicator['numerator']
    new_numerator_formula=''
    denominator_formula = indicator['denominator']
    

    #filter all dataelement only and add to list
    categorycombos_only = re.findall('\.[a-zA-Z0-9]+', indicator['numerator'] + indicator['denominator'])

    #strip off the . 
    categorycombos_only = tuple([re.sub('\.','', x)  for x in categorycombos_only])
    if not categorycombos_only:
        categorycombos_only = """(NULL)"""
    else:
        if len(categorycombos_only) == 1:
            categorycombos_only = "(\'" +str(categorycombos_only[0])+'\')'
    
    
    #remove the categoryoptioncombos from the list
    indicator_numerator = re.sub('\.[a-zA-Z0-9]+','', indicator['numerator'] + indicator['denominator'])
    
    #the remaining are dataelements only
    dataelements_only = tuple(re.findall('[a-zA-Z0-9]+' , indicator_numerator))
    if len(dataelements_only) == 1:
        dataelements_only = "(\'" +str(dataelements_only[0])+'\')'
    
    
    #filter all categoryoption combox and add to list
    for col,period in periods.iterrows():
        query = '''
                SELECT a.*, b.uid AS dataelement_uid, c.uid as categoryoptioncombo_uid
                    FROM fact_dhis_datavalue AS a , dim_dhis_dataelement b, dim_dhis_categoryoptioncombo c                    
                    WHERE (  (b.uid  in %s AND c.uid in %s ) OR b.uid  in %s ) 
                    AND a.dataelementid = b.dataelementid
                    AND a.categoryoptioncomboid = c.categoryoptioncomboid
                    AND a.sourceid = %s 
                    AND a.periodid = '%s'
                    LIMIT 1000'''%(str(dataelements_only) , str(categorycombos_only),  str(dataelements_only) ,  facility['organisationunitid'], period['periodid'] )
        values = pd.read_sql(query, get_connection())
        
        
        dataelement_categorycombo_pairs = re.findall('[a-zA-Z0-9]+\.[a-zA-Z0-9]+', numerator_formula)
        if dataelement_categorycombo_pairs:
            for pairs in dataelement_categorycombo_pairs:
                dataelement, categoryoptioncombo =  pairs.split(".") 
                try:
                    value = values.loc[values[(values['dataelement_uid']== dataelement) & (values['categoryoptioncombo_uid']== categoryoptioncombo)].index]['value'].iloc[0]
                except:
                    value = 0                 
                    
                numerator_formula = re.sub("""#{%s.%s}"""%(dataelement, categoryoptioncombo), str(value), numerator_formula)  
                
        temp_numerator_formula = numerator_formula        
        dataelements_only_pairs = re.findall('[a-z,A-Z0-9]{6,}', temp_numerator_formula)
        if dataelements_only_pairs:            
            for pairs in dataelements_only_pairs :   
                
                try:
                    value = values.loc[values[values['dataelement_uid']== pairs].index]['value'].iloc[0]
                except:         
                    value = 0       
                
                numerator_formula = re.sub("""#{%s}"""%(pairs), str(value), numerator_formula)
        numerator_formula = float(eval(numerator_formula))
        
        
        dataelement_categorycombo_pairs = re.findall('[a-zA-Z0-9]+\.[a-zA-Z0-9]+', denominator_formula)
        if dataelement_categorycombo_pairs:
            for pairs in dataelement_categorycombo_pairs:
                dataelement, categoryoptioncombo =  pairs.split(".") 
                try:
                    value = values.loc[values[(values['dataelement_uid']== dataelement) & (values['categoryoptioncombo_uid']== categoryoptioncombo)].index]['value'].iloc[0]
                except:
                    value = 0                 
                    
                denominator_formula = re.sub("""#{%s.%s}"""%(dataelement, categoryoptioncombo), str(value), denominator_formula)  
                
        temp_denominator_formula = denominator_formula        
        dataelements_only_pairs = re.findall('[a-z,A-Z0-9]{6,}', temp_denominator_formula)
        if dataelements_only_pairs:            
            for pairs in dataelements_only_pairs :   
                
                try:
                    value = values.loc[values[values['dataelement_uid']== pairs].index]['value'].iloc[0]
                except:         
                    value = 0
                
                denominator_formula = re.sub("""#{%s}"""%(pairs), str(value), denominator_formula)
        denominator_formula = float(eval(denominator_formula))
        if denominator_formula == 0:
            denominator_formula = 1
        
        

        indicator_value = {
            'indicator_id': indicator['indicatorid'],
            'value': (numerator_formula/denominator_formula),
            'year' : period['year'],
            'month': period['month']
        }
        results.append(indicator_value)
        
        numerator_formula = indicator['numerator']
        denominator_formula = indicator['denominator']
    return results
get_facility_indicator_values_singlefetch('2e21b2de-7c5b-4db7-bb1d-26930af9274d',445265,5,2014)
# Out:
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '7', 'value': 922.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '8', 'value': 908.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]

# %%
# r  =get_facility_indicator_values_singlefetch('2e21b2de-7c5b-4db7-bb1d-26930af9274d',32964,5,2014)
r  = get_facility_indicator_values_singlefetch('2e21b2de-7c5b-4db7-bb1d-26930af9274d',413098,5,2014)
# r

# %%
r
# Out:
# [{'indicator_id': 413098, 'month': '12', 'value': 281.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '10', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '1', 'value': 346.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '2', 'value': 345.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '3', 'value': 340.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '4', 'value': 353.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '5', 'value': 344.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '6', 'value': 345.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '7', 'value': 332.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '8', 'value': 351.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '9', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 413098, 'month': '11', 'value': 297.0, 'year': '2014'}]

# %%
sum =0
for x in range(0, 4):
    import time
    start_time = time.time()
    get_indicator_values('2e21b2de-7c5b-4db7-bb1d-26930af9274d',32980,5,2014)
#     print("--- %s seconds ---" % (time.time() - start_time))
    sum = sum + (time.time() - start_time)

print (sum/5)
# Out:
# 2.59544243813

# %%
sum =0
for x in range(0, 4):
    import time
    start_time = time.time()
    get_indicator_values2('2e21b2de-7c5b-4db7-bb1d-26930af9274d',32980,5,2014)
#     print("--- %s seconds ---" % (time.time() - start_time))
    sum = sum + (time.time() - start_time)

print (sum/5)
# Out:
# 1.84532160759

# %%
sum =0
for x in range(0, 4):
    import time
    start_time = time.time()
    get_facility_indicator_values_singlefetch('2e21b2de-7c5b-4db7-bb1d-26930af9274d',32980,5,2014)
#     print("--- %s seconds ---" % (time.time() - start_time))
    sum = sum + (time.time() - start_time)

print (sum/5)
# Out:
# 0.656586647034

# %%
get_facility_indicator_values_singlefetch('2e21b2de-7c5b-4db7-bb1d-26930af9274d',445265,5,2014)
# Out:
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '7', 'value': 922.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '8', 'value': 908.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'},
#  {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]

# %%
r = pd.read_sql('SELECT * from common_ward',get_connection())
# pd.read_sql('SELECT * from facilities_facility',get_connection()).columns
# pd.read_sql('SELECT * from dim_dhis_organisationunit',get_connection()).columns

# %%
def get_ward_indicator_values_singlefetch(ward_id, indicator_id, period_type, year):
    query ="""
            SELECT a.* 
            from dim_dhis_organisationunit a, facilities_facility b, common_ward c
            WHERE a.mflcode = b.code
            AND b.ward_id = c.id
            AND c.id = '%s'
            """%(ward_id)
    orgunits = pd.read_sql(query, get_connection())
    
    
    indicator = get_indicator_by_id(indicator_id).loc[0]
    periods = get_year_periodtypes(year,period_type)
    orgunits =  tuple(orgunits['organisationunitid'].values.tolist())
    results = []
    
    
    
    #define the pattern for dataelements-categorycombo and extract them
    pattern = "[a-zA-Z0-9]+\.[a-zA-Z0-9]+|[a-zA-Z0-9]+"
    numerator_formula = indicator['numerator']
    new_numerator_formula=''
    denominator_formula = indicator['denominator']
    

    #filter all dataelement only and add to list
    categorycombos_only = re.findall('\.[a-zA-Z0-9]+', indicator['numerator'] + indicator['denominator'])

    #strip off the . 
    categorycombos_only = tuple([re.sub('\.','', x)  for x in categorycombos_only])
    if not categorycombos_only:
        categorycombos_only = """(NULL)"""
    else:
        if len(categorycombos_only) == 1:
            categorycombos_only = "(\'" +str(categorycombos_only[0])+'\')'
    
    
    #remove the categoryoptioncombos from the list
    indicator_numerator = re.sub('\.[a-zA-Z0-9]+','', indicator['numerator'] + indicator['denominator'])
    
    #the remaining are dataelements only
    dataelements_only = tuple(re.findall('[a-zA-Z0-9]+' , indicator_numerator))
    if len(dataelements_only) == 1:
        dataelements_only = "(\'" +str(dataelements_only[0])+'\')'
    
    print numerator_formula
    print denominator_formula
    #filter all categoryoption combox and add to list
    for col,period in periods.iterrows():
        query = '''
                SELECT a.*, b.uid AS dataelement_uid, c.uid as categoryoptioncombo_uid
                    FROM fact_dhis_datavalue AS a , dim_dhis_dataelement b, dim_dhis_categoryoptioncombo c                    
                    WHERE (  (b.uid  in %s AND c.uid in %s ) OR b.uid  in %s ) 
                    AND a.dataelementid = b.dataelementid
                    AND a.categoryoptioncomboid = c.categoryoptioncomboid
                    AND a.sourceid in %s 
                    AND a.periodid = '%s'
                    LIMIT 1000'''%(str(dataelements_only) , str(categorycombos_only),  str(dataelements_only) ,  orgunits, period['periodid'] )
        
        values = pd.read_sql(query, get_connection())
        #convert the values to float
        values['value']=values['value'].astype(int)
        
        return values
        
        dataelement_categorycombo_pairs = re.findall('[a-zA-Z0-9]+\.[a-zA-Z0-9]+', numerator_formula)
        if dataelement_categorycombo_pairs:
            for pairs in dataelement_categorycombo_pairs:
                dataelement, categoryoptioncombo =  pairs.split(".")                 
                try:
                    value = values[ (values['dataelement_uid']==dataelement) &(values['categoryoptioncombo_uid']==categoryoptioncombo)].groupby(['dataelementid','categoryoptioncomboid']).sum()['value'].iloc[0]                    
                except:
                    value = 0                 
                
                
                numerator_formula = re.sub("""#{%s.%s}"""%(dataelement, categoryoptioncombo), str(value), numerator_formula)  
                
        temp_numerator_formula = numerator_formula        
        dataelements_only_pairs = re.findall('[a-z,A-Z0-9]{6,}', temp_numerator_formula)
        if dataelements_only_pairs:            
            for pairs in dataelements_only_pairs :   
                try:
                    value = values[ values['dataelement_uid']==dataelement].groupby(['dataelementid','categoryoptioncomboid']).sum()['value'].iloc[0]
                except:         
                    value = 0       
                
                numerator_formula = re.sub("""#{%s}"""%(pairs), str(value), numerator_formula)
        print numerator_formula
        numerator_formula = float(eval(numerator_formula))
        
        
        dataelement_categorycombo_pairs = re.findall('[a-zA-Z0-9]+\.[a-zA-Z0-9]+', denominator_formula)
        if dataelement_categorycombo_pairs:
            for pairs in dataelement_categorycombo_pairs:
                dataelement, categoryoptioncombo =  pairs.split(".") 
                try:
                    value = values[ (values['dataelement_uid']==dataelement) &(values['categoryoptioncombo_uid']==categoryoptioncombo)].groupby(['dataelementid','categoryoptioncomboid']).sum()['value'].iloc[0]                    
                except:
                    value = 0                 
                    
                denominator_formula = re.sub("""#{%s.%s}"""%(dataelement, categoryoptioncombo), str(value), denominator_formula)  
                
        temp_denominator_formula = denominator_formula        
        dataelements_only_pairs = re.findall('[a-z,A-Z0-9]{6,}', temp_denominator_formula)
        if dataelements_only_pairs:            
            for pairs in dataelements_only_pairs :   
                
                try:
                    value = values[ values['dataelement_uid']==dataelement].groupby(['dataelementid','categoryoptioncomboid']).sum()['value'].iloc[0]
                except:         
                    value = 0
                
                denominator_formula = re.sub("""#{%s}"""%(pairs), str(value), denominator_formula)
        print denominator_formula
        denominator_formula = float(eval(denominator_formula))
        if denominator_formula == 0:
            denominator_formula = 1
        
        

        indicator_value = {
            'indicator_id': indicator['indicatorid'],
            'value': (numerator_formula/denominator_formula),
            'year' : period['year'],
            'month': period['month']
        }
        results.append(indicator_value)
        
        numerator_formula = indicator['numerator']
        denominator_formula = indicator['denominator']
    return results


get_ward_indicator_values_singlefetch('661b05a3-e172-44a2-9f8c-3631b56a05b8',32980,5,2014)
# Out:
# #{HIfJ6JvWQmQ.NhSoXUMPK2K}-#{odmSZSezPsY.NhSoXUMPK2K}-#{au9lav766rM.kHFI1LYOvZF}-#{au9lav766rM.nYnnLevxuXP}-#{au9lav766rM.Qzjct1emaaj}-#{au9lav766rM.J24uZ0lCFVE}-#{au9lav766rM.B4gIWbNNUFc}-#{au9lav766rM.WmSjcUiJumX}-#{aBKk9v6MpWf.kHFI1LYOvZF}-#{aBKk9v6MpWf.nYnnLevxuXP}-#{aBKk9v6MpWf.Qzjct1emaaj}-#{aBKk9v6MpWf.J24uZ0lCFVE}-#{aBKk9v6MpWf.B4gIWbNNUFc}-#{aBKk9v6MpWf.WmSjcUiJumX}+#{siS80Yt4ul4.NhSoXUMPK2K}
# #{HIfJ6JvWQmQ.NhSoXUMPK2K}+#{siS80Yt4ul4.NhSoXUMPK2K}
#     dataelementid  periodid  sourceid  categoryoptioncomboid  \
# 0           21483    723795     32532                     15
# 1           21483    723795     32540                     15
# 2           21483    723795     32558                     15
# 3           21483    723795     54210                     15
# 4           21481    723795     32532                     15
# 5           21481    723795     32540                     15
# 6           21481    723795     32558                     15
# 7           21481    723795     54210                     15
# 8           21482    723795     32532                     15
# 9           21482    723795     32540                     15
# 10          20967    723795     32532                  23580
# 11          20967    723795     32532                  23581
# 12          20967    723795     32532                  23582
# 13          20967    723795     32540                  23580
# 14          20967    723795     32540                  23581
# 15          20967    723795     32540                  23582
# 16          20967    723795     32540                  23583
# 17          20967    723795     32540                  23584
# 18          20967    723795     32558                  23580
# 19          20967    723795     32558                  23581
# 20          20967    723795     32558                  23582
# 21          20967    723795     32558                  23583
# 22          20967    723795     32577                  23580
# 23          20967    723795     32577                  23581
# 24          20967    723795     32577                  23583
# 25          20967    723795     32577                  23584
# 26          20967    723795     32597                  23581
# 27          20967    723795     32597                  23583
#
#     attributeoptioncomboid  value                    storedby  \
# 0                       15     60                    Ben Oyoo
# 1                       15    620  Ambira Sub County Hospital
# 2                       15    180                      vashti
# 3                       15     40                      vashti
# 4                       15     40                    Ben Oyoo
# 5                       15    700  Ambira Sub County Hospital
# 6                       15    220                      vashti
# 7                       15     60                      vashti
# 8                       15     60                    Ben Oyoo
# 4    2015-12-17               None        None      None              None
# 5    2015-12-17               None        None      None              None
# 6    2015-12-17               None        None      None              None
# 7    2015-12-17               None        None      None              None
# 8    2015-12-17               None        None      None              None
# 9    2015-12-17               None        None      None              None
# 10   2015-12-17               None        None      None              None
# 11   2015-12-17               None        None      None              None
# 12   2015-12-17               None        None      None              None
# 13   2015-12-17               None        None      None              None
# 14   2015-12-17               None        None      None              None
# 15   2015-12-17               None        None      None              None
# 16   2015-12-17               None        None      None              None
# 17   2015-12-17               None        None      None              None
# 18   2015-12-17               None        None      None              None
# 19   2015-12-17               None        None      None              None
# 20   2015-12-17               None        None      None              None
# 21   2015-12-17               None        None      None              None
# 22   2015-12-17               None        None      None              None
# 23   2015-12-17               None        None      None              None
# 24   2015-12-17               None        None      None              None
# 25   2015-12-17               None        None      None              None
# 26   2015-12-17               None        None      None              None
# 27   2015-12-17               None        None      None              None
#
#    dataelement_uid categoryoptioncombo_uid
# 0      odmSZSezPsY             NhSoXUMPK2K
# 1      odmSZSezPsY             NhSoXUMPK2K
# 2      odmSZSezPsY             NhSoXUMPK2K
# 3      odmSZSezPsY             NhSoXUMPK2K
# 4      HIfJ6JvWQmQ             NhSoXUMPK2K
# 5      HIfJ6JvWQmQ             NhSoXUMPK2K
# 6      HIfJ6JvWQmQ             NhSoXUMPK2K
# 7      HIfJ6JvWQmQ             NhSoXUMPK2K
# 8      siS80Yt4ul4             NhSoXUMPK2K
# 9      siS80Yt4ul4             NhSoXUMPK2K
# 10     au9lav766rM             nYnnLevxuXP
# 11     au9lav766rM             B4gIWbNNUFc
# 12     au9lav766rM             Qzjct1emaaj
# 13     au9lav766rM             nYnnLevxuXP
# 14     au9lav766rM             B4gIWbNNUFc
# 15     au9lav766rM             Qzjct1emaaj
# 16     au9lav766rM             kHFI1LYOvZF
# 17     au9lav766rM             WmSjcUiJumX
# 18     au9lav766rM             nYnnLevxuXP
# 19     au9lav766rM             B4gIWbNNUFc
# 20     au9lav766rM             Qzjct1emaaj
# 21     au9lav766rM             kHFI1LYOvZF
# 22     au9lav766rM             nYnnLevxuXP
# 23     au9lav766rM             B4gIWbNNUFc
# 24     au9lav766rM             kHFI1LYOvZF
# 25     au9lav766rM             WmSjcUiJumX
# 26     au9lav766rM             B4gIWbNNUFc
# 27     au9lav766rM             kHFI1LYOvZF

# %%
r = get_ward_indicator_values_singlefetch('661b05a3-e172-44a2-9f8c-3631b56a05b8',445265,5,2014)
r['value']=r['value'].astype(int)
# r
# r[ (r['dataelement_uid']=='r7LJ3kCX8EZ') &(r['categoryoptioncombo_uid']=='bPNw3Km3Ug7')]
# values.loc[values[(values['dataelement_uid']== dataelement) & (values['categoryoptioncombo_uid']== categoryoptioncombo)].index]['value'].iloc[0]
r[ (r['dataelement_uid']=='r7LJ3kCX8EZ') &(r['categoryoptioncombo_uid']=='bPNw3Km3Ug7')].groupby(['dataelementid','categoryoptioncomboid']).sum()['value'].iloc[0]
# Out:
# #{r7LJ3kCX8EZ.ObiJr399QRt}
# 1
# 115

# %%
values = get_ward_indicator_values_singlefetch('661b05a3-e172-44a2-9f8c-3631b56a05b8',32980,5,2014)
# Out:
# #{HIfJ6JvWQmQ.NhSoXUMPK2K}-#{odmSZSezPsY.NhSoXUMPK2K}-#{au9lav766rM.kHFI1LYOvZF}-#{au9lav766rM.nYnnLevxuXP}-#{au9lav766rM.Qzjct1emaaj}-#{au9lav766rM.J24uZ0lCFVE}-#{au9lav766rM.B4gIWbNNUFc}-#{au9lav766rM.WmSjcUiJumX}-#{aBKk9v6MpWf.kHFI1LYOvZF}-#{aBKk9v6MpWf.nYnnLevxuXP}-#{aBKk9v6MpWf.Qzjct1emaaj}-#{aBKk9v6MpWf.J24uZ0lCFVE}-#{aBKk9v6MpWf.B4gIWbNNUFc}-#{aBKk9v6MpWf.WmSjcUiJumX}+#{siS80Yt4ul4.NhSoXUMPK2K}
# #{HIfJ6JvWQmQ.NhSoXUMPK2K}+#{siS80Yt4ul4.NhSoXUMPK2K}

# %%
values[ values['dataelement_uid']=='odmSZSezPsY']['value'].values
# Out:
# array([ 60, 620, 180,  40])

# %%
def get_ward_indicator_values_singlefetch(ward_id, indicator_id, period_type, year):
    facilities = pd.read_sql("SELECT * FROM facilities_facility WHERE ward_id = '%s' ;" %(ward_id), get_connection())
#     return facilities
    
    for col, facility in facilities.iterrows():
        print get_facility_indicator_values_singlefetch(facility.id,445265,5,2014)

get_ward_indicator_values_singlefetch('661b05a3-e172-44a2-9f8c-3631b56a05b8',32980,5,2014)
# Out:
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 2.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 4.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 1.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 1.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 2.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 3.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 1.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 4.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 7.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 6.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 2.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 3.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 16.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 18.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 6.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 27.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 30.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 38.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 25.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 48.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 41.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 37.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 54.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 51.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 28.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 23.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 35.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]

# %%
get_ward_indicator_values_singlefetch('661b05a3-e172-44a2-9f8c-3631b56a05b8',32980,5,2014)
# Out:
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 2.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 4.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 1.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 1.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 2.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 3.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 1.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 4.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 7.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 6.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 2.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 3.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 16.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 18.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 6.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 27.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 30.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 38.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 25.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 48.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 41.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 37.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 54.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 51.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 28.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 23.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 35.0, 'year': '2014'}]
# [{'indicator_id': 445265, 'month': '12', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '10', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '1', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '2', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '3', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '4', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '5', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '6', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '7', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '8', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '9', 'value': 0.0, 'year': '2014'}, {'indicator_id': 445265, 'month': '11', 'value': 0.0, 'year': '2014'}]

# %%
s = 'a+b+c'
a =  np.array([ 5 , 3 , 7 , 40])
b =  np.array([ 8 , 0 , 8 , 10])
c =  np.array([ 9 , 3 , 17 , 30])
d =  np.array([ 3 , 9 , 20 , 20])
s = re.sub('a', str(list(a)), s)
s = re.sub('b', str(list(b)), s)
s = re.sub('c', str(list(c)), s)
# Out:
#   File "<ipython-input-167-aa31970744ba>", line 1
#     [ 5  3  7 40]+[ 5  0 80 10]-[15  9 20 60]
#          ^
# SyntaxError: invalid syntax

# %%
v = np.array([ 5 , 3 , 7 , 40])
str(list(v))
# Out:
# '[5, 3, 7, 40]'
