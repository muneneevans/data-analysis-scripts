# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import json
import os
import psycopg2

# %%
#read from the backup file
def read_file(file_name):
    fileDir = os.path.dirname(os.path.realpath('__file__'))
    filename = os.path.join(fileDir, 'backups/'+file_name)
    with open(filename) as my_file:
        db_conf = json.load(my_file)
    return db_conf

# %%
# caef4fac-b2a1-4981-9d0e-f6aaf59a4eae
#data element table analysis
json_data = read_file('common_ward')
ward_dataframe = DataFrame(json_data['data']).set_index('index')

ward_dataframe.dtypes
# data_element_dframe[['dataelementname','description']]
# Out:
# _currentflag           int64
# _datecreated          object
# _effectivefrom        object
# _effectiveto          object
# _eventexecutionkey    object
# _lastaction           object
# _mergekey             object
# _sourcesystemcode     object
# active                object
# code                   int64
# constituency_id       object
# constituency_sk        int64
# deleted               object
# id                    object
# name                  object
# ward_sk                int64
# dtype: object

# %%
selected_ward = ward_dataframe[ward_dataframe['id']=='68f44791-d52d-4f25-b9f4-6f6bd9e08234']
selected_ward[['name']]
# Out:
#                  name
# index
# 73     KAHAWA WENDANI

# %%
#data element table analysis
json_data = read_file('facilities_facility')
facility_dataframe = DataFrame(json_data['data']).set_index('index')

# facility_dataframe.dtypes
# data_element_dframe[['dataelementname','description']]
# Out:
# _currentflag                      int64
# _datecreated                     object
# _effectivefrom                   object
# _effectiveto                     object
# abbreviation                     object
# active                           object
# approved                         object
# closed                           object
# closed_date                      object
# closing_reason                   object
# code                              int64
# deleted                          object
# description                      object
# facility_catchment_population    object
# facility_sk                       int64
# facility_type_id                 object
# facilitystatus_sk                 int64
# facilitytype_sk                   int64
# id                               object
# is_classified                    object
# is_published                     object
# keph_level_id                    object
# kephlevel_sk                      int64
# ...

# %%
facility_dataframe
# Out:
#        _currentflag              _datecreated            _effectivefrom  \
# index
# 0                 1                      None                      None
# 1                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 2                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 3                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 4                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 5                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 6                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 7                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 8                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 9                 1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 10                1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# 11                1  2016-01-12T00:00:00.000Z  1900-01-01T00:00:00.000Z
# ...
