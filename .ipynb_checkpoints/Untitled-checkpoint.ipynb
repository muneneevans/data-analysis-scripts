# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import requests

# %%
data = pd.read_json('https://raw.githubusercontent.com/ghosh/uiGradients/master/gradients.json')

# %%
data
# Out:
#                                    colors                    name
# 0                      [#00467F, #A5CC82]                     Sel
# 1                      [#1488CC, #2B32B2]                 Skyline
# 2                      [#ec008c, #fc6767]                  DIMIGO
# 3                      [#cc2b5e, #753a88]             Purple Love
# 4                      [#2193b0, #6dd5ed]               Sexy Blue
# 5                      [#e65c00, #F9D423]               Blooker20
# 6                      [#2b5876, #4e4376]                Sea Blue
# 7                      [#314755, #26a0da]                 Nimvelo
# 8             [#77A1D3, #79CBCA, #E684AE]                   Hazel
# 9                      [#ff6e7f, #bfe9ff]            Noon to Dusk
# 10                     [#e52d27, #b31217]                 YouTube
# 11                     [#603813, #b29f94]              Cool Brown
# 12                     [#16A085, #F4D03F]         Harmonic Energy
# ...

# %%
headers = {
    'Authorization': "Basic aGVhbHRoaXQ6aEVBTFRISVQyMDE3"
}
url = 'http://test.hiskenya.org/api/26/organisationUnits.json?fields=id,name,level,code&filter=level:in:[2]&paging=true&page=1'



r =requests

r.headers = {
    'Authorization': "Basic aGVhbHRoaXQ6aEVBTFRISVQyMDE3"
}
data = r.get('http://test.hiskenya.org/api/26/organisationUnits.json?fields=id,name,level,code&filter=level:in:[2]&paging=true&page=1')

# %%
data.content
# Out:
# '<!DOCTYPE HTML>\n<html class="loginPage">\n    <head>\n        <title>Kenya Health Information System</title>\n        <meta name="description" content="DHIS 2">\n        <meta name="keywords" content="DHIS 2">\n        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n        <script type="text/javascript" src="../javascripts/jQuery/jquery.min.js"></script>\n        <script type="text/javascript" src="login.js"></script>\n        <link type="text/css" rel="stylesheet" href="../css/widgets.css">\n        <link type="text/css" rel="stylesheet" href="../css/login.css">\n        <link type="text/css" rel="stylesheet" href="../../api/files/style/external" />\n    </head>\n    <body class="loginPage">\n    \t<h1 style="display:none">Kenya Health Information System</h1>\n    \t<div style="display:none">DHIS 2</div>\n        <div>\n                    <img id="flagArea" src="../flags/kenya.png">\n                            <span id="titleArea">Kenya Health Information S
# ...

# %%
r.headers
# Out:
# {'Content-Length': '5237', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': "default-src 'none'; style-src 'unsafe-inline'", 'X-Cache-Hits': '1', 'X-Frame-Options': 'deny', 'Access-Control-Allow-Origin': '*', 'X-Served-By': 'cache-ams4449-AMS', 'X-GitHub-Request-Id': '1988:1AB90:937CD:A005E:59C21598', 'Expires': 'Wed, 20 Sep 2017 07:24:37 GMT', 'X-Fastly-Request-ID': '22adf003f4c8fe1439de2357fedd2dbf72dda8d7', 'Date': 'Wed, 20 Sep 2017 07:19:37 GMT', 'Source-Age': '241', 'X-Cache': 'HIT', 'Accept-Ranges': 'bytes', 'Strict-Transport-Security': 'max-age=31536000', 'Connection': 'keep-alive', 'X-Geo-Block-List': '', 'Via': '1.1 varnish', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip', 'X-Timer': 'S1505891978.734171,VS0,VE1', 'Vary': 'Authorization,Accept-Encoding', 'ETag': '"58c56bb2d79226f153ed17820ec7373a80a0a696"', 'Cache-Control': 'max-age=300', 'Content-Type': 'text/plain; charset=utf-8'}

# %%
data = pd.read_json(r.content)
data
# Out:
#                                    colors                    name
# 0                      [#00467F, #A5CC82]                     Sel
# 1                      [#1488CC, #2B32B2]                 Skyline
# 2                      [#ec008c, #fc6767]                  DIMIGO
# 3                      [#cc2b5e, #753a88]             Purple Love
# 4                      [#2193b0, #6dd5ed]               Sexy Blue
# 5                      [#e65c00, #F9D423]               Blooker20
# 6                      [#2b5876, #4e4376]                Sea Blue
# 7                      [#314755, #26a0da]                 Nimvelo
# 8             [#77A1D3, #79CBCA, #E684AE]                   Hazel
# 9                      [#ff6e7f, #bfe9ff]            Noon to Dusk
# 10                     [#e52d27, #b31217]                 YouTube
# 11                     [#603813, #b29f94]              Cool Brown
# 12                     [#16A085, #F4D03F]         Harmonic Energy
# ...
