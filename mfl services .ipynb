# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

# %%
#Open the excel file
mfl_excel = pd.ExcelFile('data/mfl.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
mfl_dframe = mfl_excel.parse('Facilities')
mfl_dframe
# Out:
#        Facility Code                                 Facility Name  \
# 0              19224                        CDF Kiriari Dispensary
# 1              19310    St Jude's Huruma Community Health Services
# 2              14180                               10 Engineer VCT
# 3              17486                                  12 Engineers
# 4              18393                  3Kl Maternity & Nursing Home
# 5              14181                             3KR Health Centre
# 6              11917                  78 Tank Battalion Dispensary
# 7              13043                         7Kr Mrs Health Centre
# 8              14182                             8Th Street Clinic
# 9              18137  A To Z Quality Health Family Health Services
# 10             20346                       AAR Adams Health Centre
# 11             12861                        AAR City Centre Clinic
# 12             16796           AAR Clinic Sarit Centre (Westlands)
# ...

# %%
mfl_dframe.dtypes
# Out:
# Facility Code                int64
# Facility Name               object
# Province                    object
# County                      object
# District                    object
# Division                    object
# Type                        object
# Owner                       object
# Location                    object
# Sub Location                object
# Description of Location     object
# Constituency                object
# Nearest Town                object
# Beds                       float64
# Cots                       float64
# Official Landline           object
# Official Fax                object
# Official Mobile             object
# Official Email              object
# Official Address            object
# Official Alternate No      float64
# Town                        object
# Post Code                   object
# In Charge                   object
# Job Title of in Charge      object
# Open 24 Hours               object
# Open Weekends               object
# ...

# %%
facility_services = ['ANC','ART','BEOC','BLOOD','CAES' 'SEC','CEOC','C-IMCI','EPI','FP',
                     'GROWM','HBC','HCT','IPD','OPD','OUTREACH','PMTCT','RAD/XRAY','RHTC/RHDC',
                     'TB DIAG','TB LABS','TB TREAT','YOUTH',]
facility_services
# Out:
# ['ANC',
#  'ART',
#  'BEOC',
#  'BLOOD',
#  'CAESSEC',
#  'CEOC',
#  'C-IMCI',
#  'EPI',
#  'FP',
#  'GROWM',
#  'HBC',
#  'HCT',
#  'IPD',
#  'OPD',
#  'OUTREACH',
#  'PMTCT',
#  'RAD/XRAY',
#  'RHTC/RHDC',
#  'TB DIAG',
#  'TB LABS',
#  'TB TREAT',
#  'YOUTH']
